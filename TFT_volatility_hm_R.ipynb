# %% [markdown]
# <a href="https://colab.research.google.com/github/iskra3138/tft/blob/master/TFT_volatility_hm_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ref.
# - https://github.com/google-research/google-research/blob/master/tft/script_train_fixed_params.py
# - https://aihub.cloud.google.com/u/0/p/products%2F9f39ad8d-ad81-4fd9-8238-5186d36db2ec

# %%
# Uses pip3 to install necessary packages 
# !pip3 install pyunpack wget patool plotly cufflinks --user 
# Resets the IPython kernel to import the installed package. 
import IPython 
app = IPython.Application.instance() 
app.kernel.do_shutdown(True)

# %%
# !nvidia-smi
# Out:
# Mon Jun  8 10:28:21 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    25W / 250W |      0MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# if the code is in goole drive, the following cell doesn't need to run.

# %%
# install to download only tft directory 
#!pip install git+git://github.com/HR/github-clone#egg=ghclone
#!ghclone https://github.com/google-research/google-research/tree/master/tft

# %%
from google.colab import drive

# %%
drive.mount('/Gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /Gdrive

# %%
cd '/Gdrive/My Drive/TFT'
# Out:
# /Gdrive/My Drive/TFT

# %%
#!ghclone https://github.com/google-research/google-research/tree/master/tft

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
cd tft
# Out:
# /Gdrive/My Drive/TFT/tft

# %%
# where $EXPT can be any of {volatility, electricity, traffic, favorita}, 
# and $OUTPUT_FOLDER denotes the root folder in which experiment outputs are saved.
EXPT='volatility'
OUTPUT_FOLDER='volatility_test'

# %%
# download $EXPT data
# !python3 -m script_download_data $EXPT $OUTPUT_FOLDER
# Out:
# #### Running download script ###
# Resetting data folder...
# Getting volatility data...
# Pulling data from https://realized.oxford-man.ox.ac.uk/images/oxfordmanrealizedvolatilityindices.zip to volatility_test/data/volatility/oxfordmanrealizedvolatilityindices.zip
# done
# Unzipping file: volatility_test/data/volatility/oxfordmanrealizedvolatilityindices.zip
# Done.
# Unzip complete. Adding extra inputs
# /Gdrive/My Drive/TFT/tft/script_download_data.py:121: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   df['days_from_start'] = (dates - pd.datetime(2000, 1, 3)).days
# Completed formatting, saving to volatility_test/data/volatility/formatted_omi_vol.csv
# Done.
# Download completed.

# %%
import argparse
import datetime as dte
import os

import data_formatters.base
import expt_settings.configs
import libs.hyperparam_opt
import libs.tft_model
import libs.utils as utils
import numpy as np
import pandas as pd
import tensorflow.compat.v1 as tf

# %%
ExperimentConfig = expt_settings.configs.ExperimentConfig
HyperparamOptManager = libs.hyperparam_opt.HyperparamOptManager
ModelClass = libs.tft_model.TemporalFusionTransformer

# %%
# args for electricity testing from gpu
name, output_folder, use_tensorflow_with_gpu = EXPT, OUTPUT_FOLDER, True

print("Using output folder {}".format(output_folder))

config = ExperimentConfig(name, output_folder)
formatter = config.make_data_formatter()
# Out:
# Using output folder volatility_test

# %%
expt_name=name
use_gpu=use_tensorflow_with_gpu
model_folder=os.path.join(config.model_folder, "fixed")
data_csv_path=config.data_csv_path
data_formatter=formatter
#use_testing_mode=False

# %%
#num_repeats = 1

if not isinstance(data_formatter, data_formatters.base.GenericDataFormatter):
  raise ValueError(
      "Data formatters should inherit from" +
      "AbstractDataFormatter! Type={}".format(type(data_formatter)))

# %%
# Tensorflow setup
default_keras_session = tf.keras.backend.get_session()

# %%
if use_gpu:
  tf_config = utils.get_default_tensorflow_config(tf_device="gpu", gpu_id=0)

else:
  tf_config = utils.get_default_tensorflow_config(tf_device="cpu")

print("*** Training from defined parameters for {} ***".format(expt_name))
# Out:
# Selecting GPU ID=0
# WARNING:tensorflow:From /Gdrive/My Drive/TFT/tft/libs/utils.py:153: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# *** Training from defined parameters for volatility ***

# %%
# !pip install ipython-autotime

# %load_ext autotime
# Out:
# Collecting ipython-autotime
#   Downloading https://files.pythonhosted.org/packages/e6/f9/0626bbdb322e3a078d968e87e3b01341e7890544de891d0cb613641220e6/ipython-autotime-0.1.tar.bz2
# Building wheels for collected packages: ipython-autotime
#   Building wheel for ipython-autotime (setup.py) ... done
#   Created wheel for ipython-autotime: filename=ipython_autotime-0.1-cp36-none-any.whl size=1832 sha256=375ed5ff4f671218e30fe16321869b296c09f2dd0d2d9b5ee73e6bc5f8cbbc96
#   Stored in directory: /root/.cache/pip/wheels/d2/df/81/2db1e54bc91002cec40334629bc39cfa86dff540b304ebcd6e
# Successfully built ipython-autotime
# Installing collected packages: ipython-autotime
# Successfully installed ipython-autotime-0.1

# %%
print("Loading & splitting data...")
raw_data = pd.read_csv(data_csv_path, index_col=0)
train, valid, test = data_formatter.split_data(raw_data)
train_samples, valid_samples = data_formatter.get_num_samples_for_calibration()
# Out:
# Loading & splitting data...
# Formatting train-valid-test splits.
# Setting scalers with training data...
# time: 1.18 s

# %%
print (train_samples, valid_samples)
# Out:
# -1 -1
# time: 1.12 ms

# %%
# Sets up default params
fixed_params = data_formatter.get_experiment_params()
params = data_formatter.get_default_model_params()
params["model_folder"] = model_folder
# Out:
# time: 1.53 ms

# %%
# Sets up hyperparam manager
print("*** Loading hyperparm manager ***")
opt_manager = HyperparamOptManager({k: [params[k]] for k in params},
                                    fixed_params, model_folder)
# Out:
# *** Loading hyperparm manager ***
# time: 5.53 ms

# %%
# Training -- one iteration only
print("*** Running calibration ***")
print("Params Selected:")
for k in params:
  print("{}: {}".format(k, params[k]))
# Out:
# *** Running calibration ***
# Params Selected:
# dropout_rate: 0.3
# hidden_layer_size: 160
# learning_rate: 0.01
# minibatch_size: 64
# max_gradient_norm: 0.01
# num_heads: 1
# stack_size: 1
# model_folder: volatility_test/saved_models/volatility/fixed
# time: 1.63 ms

# %% [markdown]
# Next, we train a TFT model by subsampling the data in the training and validation sets.

# %%
tf.reset_default_graph()
with tf.Graph().as_default(), tf.Session(config=tf_config) as sess:

    tf.keras.backend.set_session(sess)
    params = opt_manager.get_next_parameters()
    # Create a TFT model
    model = ModelClass(params, use_cudnn=True) # Run model on GPU using CuDNNLSTM cells

    # Sample data into minibatches for training
    if not model.training_data_cached():
        model.cache_batched_data(train, "train", num_samples=train_samples)
        model.cache_batched_data(valid, "valid", num_samples=valid_samples)

    # Train and save model
    model.fit()
    model.save(model_folder)
# Out:
# Resetting temp folder...
# *** TemporalFusionTransformer params ***
# # dropout_rate = 0.3
# # hidden_layer_size = 160
# # learning_rate = 0.01
# # max_gradient_norm = 0.01
# # minibatch_size = 64
# # model_folder = volatility_test/saved_models/volatility/fixed
# # num_heads = 1
# # stack_size = 1
# # total_time_steps = 257
# # num_encoder_steps = 252
# # num_epochs = 100
# # early_stopping_patience = 5
# # multiprocessing_workers = 5
# # column_definition = [('Symbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.ID: 4>), ('date', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('log_vol', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('open_to_close', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('days_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_week', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_month', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('week_of_year', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('month', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('Region', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# # input_size = 8
# # output_size = 1
# # category_counts = [7, 31, 53, 12, 4]
# # input_obs_loc = [0]
# # static_input_loc = [7]
# # known_regular_inputs = [2]
# # known_categorical_inputs = [0, 1, 2, 3, 4]
# WARNING:tensorflow:From /Gdrive/My Drive/TFT/tft/libs/tft_model.py:1039: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/initializers.py:119: calling RandomUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /Gdrive/My Drive/TFT/tft/libs/tft_model.py:942: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 257, 8)]     0
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 5)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257)]        0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential_4 (Sequential)       (None, 257, 160)     640         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 160)]        0           sequential_4[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 160)          0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 160)          25760       flatten[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation (Activation)         (None, 160)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1, 160)       25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 160)          25760       activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 1, 160)       0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 160)          0           dense_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 1, 160)       25760       activation_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            161         dropout[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            161         dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1, 160)       0           dense_9[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            161         flatten[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 1)            0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 1, 160)       25760       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 1, 160)       25760       dropout_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 1)            0           dense_3[0][0]
#                                                                  multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1, 160)       0           dense_10[0][0]
#                                                                  dense_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization (LayerNorma (None, 1)            2           add[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 1, 160)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 1)            0           layer_normalization[0][0]
# __________________________________________________________________________________________________
# layer_normalization_1 (LayerNor (None, 1, 160)       320         add_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 1)]       0           activation_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_1[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1, 160)       0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 160)]        0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 160)          25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 160)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 3)]     0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 160)          25760       activation_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257)]        0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257)]        0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257)]        0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257)]        0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 1)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 160)          0           dense_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 257, 160)     320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_2 (TimeDistrib (None, 257, 160)     320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 257, 160)     1120        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 257, 160)     4960        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential_2 (Sequential)       (None, 257, 160)     8480        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# sequential_3 (Sequential)       (None, 257, 160)     1920        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, 257, 160)     320         tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 160)          25760       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 160)          25760       dropout_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 160, 1) 0           time_distributed_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 160, 5) 0           time_distributed_2[0][0]
#                                                                  sequential[1][0]
#                                                                  sequential_1[1][0]
#                                                                  sequential_2[1][0]
#                                                                  sequential_3[1][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 160, 1) 0           time_distributed[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 160)          0           dense_14[0][0]
#                                                                  dense_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160, 1) 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160, 5) 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160, 1) 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 160)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160, 7) 0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_2 (LayerNor (None, 160)          320         add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 1120)]  0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160, 5)]  0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_4 (TimeDistrib (None, 252, 160)     179360      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_5 (TimeDistrib (None, 1, 160)       25600       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 800)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           time_distributed_4[0][0]
#                                                                  time_distributed_5[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 252, 160)]   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_38 (TimeDistri (None, 5, 160)       128160      tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_39 (TimeDistri (None, 1, 160)       25600       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_9 (TimeDistrib (None, 252, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_13 (TimeDistri (None, 252, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_17 (TimeDistri (None, 252, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_21 (TimeDistri (None, 252, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_25 (TimeDistri (None, 252, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_29 (TimeDistri (None, 252, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_33 (TimeDistri (None, 252, 160)     25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160)]     0           time_distributed_38[0][0]
#                                                                  time_distributed_39[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160)]     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_6 (TimeDistrib (None, 252, 160)     25760       activation_7[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 252, 160)     0           time_distributed_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 252, 160)     0           time_distributed_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 252, 160)     0           time_distributed_17[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 252, 160)     0           time_distributed_21[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 252, 160)     0           time_distributed_25[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 252, 160)     0           time_distributed_29[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 252, 160)     0           time_distributed_33[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 5, 160)       0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_43 (TimeDistri (None, 5, 160)       25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_47 (TimeDistri (None, 5, 160)       25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_51 (TimeDistri (None, 5, 160)       25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_55 (TimeDistri (None, 5, 160)       25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_59 (TimeDistri (None, 5, 160)       25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 252, 160)     0           time_distributed_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_10 (TimeDistri (None, 252, 160)     25760       activation_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_14 (TimeDistri (None, 252, 160)     25760       activation_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_18 (TimeDistri (None, 252, 160)     25760       activation_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_22 (TimeDistri (None, 252, 160)     25760       activation_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_26 (TimeDistri (None, 252, 160)     25760       activation_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_30 (TimeDistri (None, 252, 160)     25760       activation_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_34 (TimeDistri (None, 252, 160)     25760       activation_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_40 (TimeDistri (None, 5, 160)       25760       activation_16[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 5, 160)       0           time_distributed_43[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 5, 160)       0           time_distributed_47[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 5, 160)       0           time_distributed_51[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 5, 160)       0           time_distributed_55[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 5, 160)       0           time_distributed_59[0][0]
# __________________________________________________________________________________________________
# time_distributed_7 (TimeDistrib (None, 252, 7)       1127        dropout_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_8 (TimeDistrib (None, 252, 7)       1127        dropout_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 252, 160)     0           time_distributed_10[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 252, 160)     0           time_distributed_14[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 252, 160)     0           time_distributed_18[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 252, 160)     0           time_distributed_22[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 252, 160)     0           time_distributed_26[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 252, 160)     0           time_distributed_30[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 252, 160)     0           time_distributed_34[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 160)          25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 160)          25760       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 5, 160)       0           time_distributed_40[0][0]
# __________________________________________________________________________________________________
# time_distributed_44 (TimeDistri (None, 5, 160)       25760       activation_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_48 (TimeDistri (None, 5, 160)       25760       activation_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_52 (TimeDistri (None, 5, 160)       25760       activation_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_56 (TimeDistri (None, 5, 160)       25760       activation_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_60 (TimeDistri (None, 5, 160)       25760       activation_22[0][0]
# __________________________________________________________________________________________________
# time_distributed_3 (TimeDistrib (None, 252, 7)       7847        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 252, 7)       0           time_distributed_7[0][0]
#                                                                  time_distributed_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_11 (TimeDistri (None, 252, 160)     25760       dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_12 (TimeDistri (None, 252, 160)     25760       dropout_7[0][0]
# __________________________________________________________________________________________________
# time_distributed_15 (TimeDistri (None, 252, 160)     25760       dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_16 (TimeDistri (None, 252, 160)     25760       dropout_8[0][0]
# __________________________________________________________________________________________________
# time_distributed_19 (TimeDistri (None, 252, 160)     25760       dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_20 (TimeDistri (None, 252, 160)     25760       dropout_9[0][0]
# __________________________________________________________________________________________________
# time_distributed_23 (TimeDistri (None, 252, 160)     25760       dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_24 (TimeDistri (None, 252, 160)     25760       dropout_10[0][0]
# __________________________________________________________________________________________________
# time_distributed_27 (TimeDistri (None, 252, 160)     25760       dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_28 (TimeDistri (None, 252, 160)     25760       dropout_11[0][0]
# __________________________________________________________________________________________________
# time_distributed_31 (TimeDistri (None, 252, 160)     25760       dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_32 (TimeDistri (None, 252, 160)     25760       dropout_12[0][0]
# __________________________________________________________________________________________________
# time_distributed_35 (TimeDistri (None, 252, 160)     25760       dropout_13[0][0]
# __________________________________________________________________________________________________
# time_distributed_36 (TimeDistri (None, 252, 160)     25760       dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 160)          0           dense_20[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 160)          0           dense_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_41 (TimeDistri (None, 5, 5)         805         dropout_14[0][0]
# __________________________________________________________________________________________________
# time_distributed_42 (TimeDistri (None, 5, 5)         805         dropout_14[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 5, 160)       0           time_distributed_44[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 5, 160)       0           time_distributed_48[0][0]
# __________________________________________________________________________________________________
# dropout_17 (Dropout)            (None, 5, 160)       0           time_distributed_52[0][0]
# __________________________________________________________________________________________________
# dropout_18 (Dropout)            (None, 5, 160)       0           time_distributed_56[0][0]
# __________________________________________________________________________________________________
# dropout_19 (Dropout)            (None, 5, 160)       0           time_distributed_60[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 252, 7)       0           time_distributed_3[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 252, 160)     0           time_distributed_11[0][0]
#                                                                  time_distributed_12[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 252, 160)     0           time_distributed_15[0][0]
#                                                                  time_distributed_16[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 252, 160)     0           time_distributed_19[0][0]
#                                                                  time_distributed_20[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 252, 160)     0           time_distributed_23[0][0]
#                                                                  time_distributed_24[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 252, 160)     0           time_distributed_27[0][0]
#                                                                  time_distributed_28[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 252, 160)     0           time_distributed_31[0][0]
#                                                                  time_distributed_32[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 252, 160)     0           time_distributed_35[0][0]
#                                                                  time_distributed_36[0][0]
# __________________________________________________________________________________________________
# dense_21 (Dense)                (None, 160)          25760       activation_5[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 160)          25760       activation_6[0][0]
# __________________________________________________________________________________________________
# time_distributed_37 (TimeDistri (None, 5, 5)         4005        tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 5, 5)         0           time_distributed_41[0][0]
#                                                                  time_distributed_42[0][0]
# __________________________________________________________________________________________________
# time_distributed_45 (TimeDistri (None, 5, 160)       25760       dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_46 (TimeDistri (None, 5, 160)       25760       dropout_15[0][0]
# __________________________________________________________________________________________________
# time_distributed_49 (TimeDistri (None, 5, 160)       25760       dropout_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_50 (TimeDistri (None, 5, 160)       25760       dropout_16[0][0]
# __________________________________________________________________________________________________
# time_distributed_53 (TimeDistri (None, 5, 160)       25760       dropout_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_54 (TimeDistri (None, 5, 160)       25760       dropout_17[0][0]
# __________________________________________________________________________________________________
# time_distributed_57 (TimeDistri (None, 5, 160)       25760       dropout_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_58 (TimeDistri (None, 5, 160)       25760       dropout_18[0][0]
# __________________________________________________________________________________________________
# time_distributed_61 (TimeDistri (None, 5, 160)       25760       dropout_19[0][0]
# __________________________________________________________________________________________________
# time_distributed_62 (TimeDistri (None, 5, 160)       25760       dropout_19[0][0]
# __________________________________________________________________________________________________
# layer_normalization_6 (LayerNor (None, 252, 7)       14          add_6[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_8[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_10[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_12[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 252, 160)     0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_14[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 160)          0           dense_21[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 160)          0           dense_25[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 5, 5)         0           time_distributed_37[0][0]
#                                                                  multiply_16[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 5, 160)       0           time_distributed_45[0][0]
#                                                                  time_distributed_46[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 5, 160)       0           time_distributed_49[0][0]
#                                                                  time_distributed_50[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 5, 160)       0           time_distributed_53[0][0]
#                                                                  time_distributed_54[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 5, 160)       0           time_distributed_57[0][0]
#                                                                  time_distributed_58[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 5, 160)       0           time_distributed_61[0][0]
#                                                                  time_distributed_62[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 252, 7)       0           layer_normalization_6[0][0]
# __________________________________________________________________________________________________
# layer_normalization_7 (LayerNor (None, 252, 160)     320         add_7[0][0]
# __________________________________________________________________________________________________
# layer_normalization_8 (LayerNor (None, 252, 160)     320         add_8[0][0]
# __________________________________________________________________________________________________
# layer_normalization_9 (LayerNor (None, 252, 160)     320         add_9[0][0]
# __________________________________________________________________________________________________
# layer_normalization_10 (LayerNo (None, 252, 160)     320         add_10[0][0]
# __________________________________________________________________________________________________
# layer_normalization_11 (LayerNo (None, 252, 160)     320         add_11[0][0]
# __________________________________________________________________________________________________
# layer_normalization_12 (LayerNo (None, 252, 160)     320         add_12[0][0]
# __________________________________________________________________________________________________
# layer_normalization_13 (LayerNo (None, 252, 160)     320         add_13[0][0]
# ...
#                                                                  time_distributed_64[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 160)]   0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 160)          0           tf_op_layer_TemporalFusionTransfo
#                                                                  multiply_4[0][0]
# __________________________________________________________________________________________________
# add_20 (Add)                    (None, 257, 160)     0           multiply_23[0][0]
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# layer_normalization_3 (LayerNor (None, 160)          320         add_3[0][0]
# __________________________________________________________________________________________________
# layer_normalization_20 (LayerNo (None, 257, 160)     320         add_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 1, 160)]     0           layer_normalization_3[0][0]
# __________________________________________________________________________________________________
# time_distributed_65 (TimeDistri (None, 257, 160)     25760       layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# time_distributed_66 (TimeDistri (None, 1, 160)       25600       tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 257, 160)]   0           time_distributed_65[0][0]
#                                                                  time_distributed_66[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 257, 160)     0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# time_distributed_67 (TimeDistri (None, 257, 160)     25760       activation_23[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 257, 160)     0           time_distributed_67[0][0]
# __________________________________________________________________________________________________
# time_distributed_68 (TimeDistri (None, 257, 160)     25760       dropout_21[0][0]
# __________________________________________________________________________________________________
# time_distributed_69 (TimeDistri (None, 257, 160)     25760       dropout_21[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 257, 160)     0           time_distributed_68[0][0]
#                                                                  time_distributed_69[0][0]
# __________________________________________________________________________________________________
# add_21 (Add)                    (None, 257, 160)     0           layer_normalization_20[0][0]
#                                                                  multiply_24[0][0]
# __________________________________________________________________________________________________
# layer_normalization_21 (LayerNo (None, 257, 160)     320         add_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(3,)]               0           layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [()]                 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(3,)]               0           layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [()]                 0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(1,)]               0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(1,)]               0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(2,)]               0           tf_op_layer_TemporalFusionTransfo
#                                                                  tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None)]       0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# dense_96 (Dense)                (None, 257, 160)     25600       layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# dense_97 (Dense)                (None, 257, 160)     25600       layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, None, None)] 0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 257, 257)     0           dense_96[0][0]
#                                                                  dense_97[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, None, None)   0           tf_op_layer_TemporalFusionTransfo
# __________________________________________________________________________________________________
# add_22 (Add)                    (None, 257, 257)     0           lambda[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 257, 257)     0           add_22[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 257, 257)     0           activation_24[0][0]
# __________________________________________________________________________________________________
# dense_95 (Dense)                (None, 257, 160)     25600       layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 257, 160)     0           dropout_22[0][0]
#                                                                  dense_95[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 257, 160)     0           lambda_2[0][0]
# __________________________________________________________________________________________________
# dense_98 (Dense)                (None, 257, 160)     25600       dropout_23[0][0]
# __________________________________________________________________________________________________
# dropout_24 (Dropout)            (None, 257, 160)     0           dense_98[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 257, 160)     0           dropout_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_70 (TimeDistri (None, 257, 160)     25760       dropout_25[0][0]
# __________________________________________________________________________________________________
# time_distributed_71 (TimeDistri (None, 257, 160)     25760       dropout_25[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 257, 160)     0           time_distributed_70[0][0]
#                                                                  time_distributed_71[0][0]
# __________________________________________________________________________________________________
# add_23 (Add)                    (None, 257, 160)     0           multiply_25[0][0]
#                                                                  layer_normalization_21[0][0]
# __________________________________________________________________________________________________
# layer_normalization_22 (LayerNo (None, 257, 160)     320         add_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_72 (TimeDistri (None, 257, 160)     25760       layer_normalization_22[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 257, 160)     0           time_distributed_72[0][0]
# __________________________________________________________________________________________________
# time_distributed_73 (TimeDistri (None, 257, 160)     25760       activation_25[0][0]
# __________________________________________________________________________________________________
# dropout_26 (Dropout)            (None, 257, 160)     0           time_distributed_73[0][0]
# __________________________________________________________________________________________________
# time_distributed_74 (TimeDistri (None, 257, 160)     25760       dropout_26[0][0]
# __________________________________________________________________________________________________
# time_distributed_75 (TimeDistri (None, 257, 160)     25760       dropout_26[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 257, 160)     0           time_distributed_74[0][0]
#                                                                  time_distributed_75[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 257, 160)     0           layer_normalization_22[0][0]
#                                                                  multiply_26[0][0]
# __________________________________________________________________________________________________
# layer_normalization_23 (LayerNo (None, 257, 160)     320         add_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_76 (TimeDistri (None, 257, 160)     25760       layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# time_distributed_77 (TimeDistri (None, 257, 160)     25760       layer_normalization_23[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 257, 160)     0           time_distributed_76[0][0]
#                                                                  time_distributed_77[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 257, 160)     0           multiply_27[0][0]
#                                                                  layer_normalization_20[0][0]
# __________________________________________________________________________________________________
# layer_normalization_24 (LayerNo (None, 257, 160)     320         add_25[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_TemporalFusionTrans [(None, 5, 160)]     0           layer_normalization_24[0][0]
# __________________________________________________________________________________________________
# time_distributed_78 (TimeDistri (None, 5, 3)         483         tf_op_layer_TemporalFusionTransfo
# ==================================================================================================
# Total params: 3,156,068
# Trainable params: 3,156,068
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Cached data "train" updated
# Cached data "valid" updated
# *** Fitting TemporalFusionTransformer ***
# Getting batched_data
# Using cached training data
# Using cached validation data
# Using keras standard fit
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 101946 samples, validate on 7635 samples
# Epoch 1/100
# 101946/101946 [==============================] - 274s 3ms/sample - loss: 0.4689 - val_loss: 0.3935
# Epoch 2/100
# 101946/101946 [==============================] - 247s 2ms/sample - loss: 0.4388 - val_loss: 0.4396
# Epoch 3/100
# 101946/101946 [==============================] - 247s 2ms/sample - loss: 0.4347 - val_loss: 0.3971
# Epoch 4/100
# 101946/101946 [==============================] - 246s 2ms/sample - loss: 0.4330 - val_loss: 0.4231
# Epoch 5/100
# 101946/101946 [==============================] - 246s 2ms/sample - loss: 0.4289 - val_loss: 0.4068
# Epoch 6/100
# 101946/101946 [==============================] - 246s 2ms/sample - loss: 0.4279 - val_loss: 0.4322
# Cannot load from volatility_test/saved_models/volatility/fixed/tmp, skipping ...
# WARNING:tensorflow:From /Gdrive/My Drive/TFT/tft/libs/utils.py:174: The name tf.get_collection is deprecated. Please use tf.compat.v1.get_collection instead.
#
# WARNING:tensorflow:From /Gdrive/My Drive/TFT/tft/libs/utils.py:174: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /Gdrive/My Drive/TFT/tft/libs/utils.py:175: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# Model saved to: volatility_test/saved_models/volatility/fixed/TemporalFusionTransformer.ckpt
# time: 25min 39s

# %% [markdown]
# To evaluate model performance, we reload the serialised model and compute P50 and P90 losses.

# %%
tf.reset_default_graph()
with tf.Graph().as_default(), tf.Session(config=tf_config) as sess:

    tf.keras.backend.set_session(sess)
    #best_params = opt_manager.get_best_params()
    # Create a new model & load weights
    model = ModelClass(params, use_cudnn=True)
    model.load(model_folder)
    
    # Make forecasts
    output_map = model.predict(test, return_targets=True)

    targets = data_formatter.format_predictions(output_map["targets"])

    # Format predictions
    p50_forecast = data_formatter.format_predictions(output_map["p50"])
    p90_forecast = data_formatter.format_predictions(output_map["p90"])

    def extract_numerical_data(data):
        """Strips out forecast time and identifier columns."""
        return data[[
          col for col in data.columns
          if col not in {"forecast_time", "identifier"}
        ]]

    # Compute Losses
    p50_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p50_forecast),
        0.5)
    p90_loss = utils.numpy_normalised_quantile_loss(
        extract_numerical_data(targets), extract_numerical_data(p90_forecast),
        0.9)
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   7.2394121e-01  1.4221710e-01 -4.8328486e-01  7.1859604e-01
#  -5.4687691e-01  9.2595798e-01  3.6929384e-02 -9.7084172e-02
#   2.4744347e-01  3.3223677e-01  4.7829893e-01 -3.7946758e-01
#  -1.0797397e+00 -3.5035563e-01  8.9912757e-02 -7.4466103e-01
#  -2.5823772e-01  2.9827848e-01 -3.7971592e-01  4.0430340e-01
#  -1.7156051e-01  6.6864133e-01 -6.4537168e-01  8.9758027e-01
#   3.1264770e-01  1.0574191e-01 -4.5599225e-01  4.2721418e-01
#   4.1115675e-03  5.0053751e-01  1.9334669e-01 -4.2820770e-01
#  -3.2271406e-01 -6.9662869e-01  2.8277698e-01 -3.1757884e-02
#  -3.9949363e-01 -2.6972589e-01  2.4364826e-01 -5.9507424e-01
#  -2.5105217e-01 -6.0672443e-02 -3.1091112e-01 -4.2418852e-01
#   6.1642516e-01  1.7750435e-01  1.1398838e-01 -2.1874814e-01
#  -6.0363363e-02 -4.6513936e-01 -4.7101933e-01  8.9392245e-01
#   7.9250693e-01  1.6398588e-01  1.7165676e-01  8.6701918e-01
#   2.0951720e-01 -4.4608802e-01  3.8845199e-01  7.9437904e-03
#  -3.4518147e-01 -5.8864281e-02 -2.7562462e-02  3.6878759e-01
#  -2.3818461e-02 -4.5808607e-01  5.8821659e-04  6.0893965e-01
#  -3.2761922e-01 -3.2679233e-01 -1.9549809e-01 -4.5082742e-01
#   1.2969317e-01 -6.8119961e-01  9.9359766e-02  1.1226842e-01
#   5.9903628e-01 -4.4111651e-01  1.1420857e-01 -2.6613793e-01
#  -3.5464042e-01  6.6335839e-01  2.4223326e-01 -2.0443864e-02
#   8.5701144e-01  1.1723822e-01 -6.4489102e-01  1.7131107e-01
#  -3.0415043e-01 -4.3837225e-01  3.5150716e-01  8.8805482e-02
#   3.2624501e-01 -9.0235077e-02  2.1404351e-01 -4.6449029e-01
#  -2.7408567e-01  3.6918795e-01 -3.7644288e-01  8.8519007e-01
#   3.9440897e-01  1.0881969e+00  6.5521216e-01  3.1173855e-01
#   3.3649594e-01 -1.6796226e-03  3.7381619e-01 -7.8814679e-01
#  -4.4003159e-01  5.3103548e-01  2.0287456e-01 -2.8659645e-01
#   5.4972905e-01  4.0803868e-01  5.5748308e-01  1.7705512e-01
#   9.2022069e-02  7.2532946e-01 -2.2584586e-01  4.2873749e-01
#  -5.8750796e-01  1.9906399e-01 -5.5878574e-01 -1.7318565e-01
#  -2.2118656e-01  2.2726089e-01 -3.1059328e-02  6.7535467e-02
#  -2.0811623e-01 -1.7548558e-01  3.0270666e-01  7.1167529e-02
#  -6.7178130e-01 -6.5312636e-01  4.1037986e-01  3.9624140e-01
#   9.3991734e-02 -7.1224564e-01  1.7450210e-01  4.9055418e-01
#   2.4532732e-01 -6.4445388e-01  6.6002846e-02  5.2989334e-01]
# tensor_name:  TemporalFusionTransformer/layer_normalization_2/gamma
# [ 1.981522   -0.18573435  0.9196615   1.6367642   0.5847462   0.7476944
#   0.53638875  1.525157    0.6834916   1.7975068   1.2544441   1.0199803
#   2.2498684  -0.08681571 -0.24923082  0.3969138   2.2861896   1.4833925
#   0.11946809 -0.5333284  -0.12186758  1.2655352   0.61290526  1.6433703
#   0.2991019   0.95483106  1.5464238   0.17222007  1.2620775   1.2475365
#   0.7674473   1.6174358   0.7711289   0.13388309  1.495414    0.5867483
#   1.3183297  -0.68868524  0.780185    0.6125811   0.9195788   0.18082137
#   1.6131767   0.35620782  0.82527256 -0.03622824  1.8107425  -0.16098541
#   1.0384514   2.6796794   0.59820026  0.26881054  0.82136595  0.3503943
#   0.79678935  2.411625   -0.10716918  0.39232585  1.4754803  -0.10340089
#  -0.25125107  1.475158    0.64251494  0.92079026  0.4206259   0.00490617
#   1.4228551   2.330466    1.0016799   0.7934311   0.6408777   1.9968655
#   1.2000115   1.0298972   0.7293467  -0.03383257  0.12994143  0.37422037
#   0.8851673   1.2196709  -0.2988425   0.9861902   1.2847095   1.4580263
#   0.21207634  1.0447015   1.1182923   1.2629356   0.02668512  1.4853079
#   0.4899175   0.67011106  1.7356777   1.3171228   0.9672132   0.3796227
#   0.23442431  1.754979    1.410968   -0.03028708 -0.4841555  -0.14066628
#  -0.51365465  0.7967084  -0.4248101   0.5598965   1.4321047   0.87449014
#   1.251474    1.0403466  -0.30464637  1.2070649   1.06283     1.4018011
#   0.7557006   0.05748295  0.15061545  0.31923327  2.4619443   1.0269828
#   0.836461    1.5517466   1.7450426   2.64918     1.5540891   1.3174652
#   0.80105615 -0.39244947  0.03595992  0.44591108  1.2310184   0.37344548
#   0.54390574 -0.09220815  0.02913679  1.9739462   0.53341585  1.0939878
#  -0.04668533  0.48183903  1.4312472   1.4664445   0.85053     0.24060108
#   0.8320725   1.255179    1.1480796   0.22990541  0.6653161   2.5945733
#   2.0643876   2.1148155   1.5709351  -0.37745884  0.2781805   1.065677
#   1.4573679   1.6645947   0.64975554  1.5095729 ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_20/beta
# [ 4.54239212e-02  3.78447622e-01 -1.75341200e-02 -1.09749556e-01
#  -2.42395446e-01 -3.35068226e-01 -2.32679565e-02 -1.02513663e-01
#   1.79423660e-01  1.43579662e+00 -1.92403644e-02 -5.47573417e-02
#  -1.22936435e-01 -4.16952744e-02 -5.25889881e-02 -3.53004217e-01
#  -2.69615860e-03 -5.88728189e-02 -1.57156155e-01 -3.23807262e-02
#  -2.44302630e-01 -1.59205094e-01 -1.13837409e+00 -2.64469534e-01
#  -3.30594629e-01 -1.71607181e-01 -2.27709152e-02 -1.37018442e-01
#  -1.51660025e-01 -3.26238364e-01  1.53893873e-01 -9.00958839e-04
#  -2.82376349e-01  8.71880114e-01 -1.08247995e-01  3.36853027e-01
#  -2.85418779e-01 -6.10363632e-02 -3.11521161e-02 -3.05704139e-02
#   1.61416137e+00 -8.67223591e-02 -3.16207290e-01 -2.31285810e+00
#  -4.23909239e-02 -4.31015203e-03 -4.96464461e-01 -3.00779313e-01
#  -1.06091620e-02 -9.67342705e-02  3.82485181e-01  1.37195385e+00
#  -1.89552695e-01 -1.08192921e-01 -1.23695247e-01 -1.99253261e-01
#  -2.92628109e-01 -3.67430300e-01 -1.65728346e-01  1.32627502e-01
#  -8.39342535e-01  1.63312435e-01 -3.56257409e-02  1.12603962e+00
#  -6.90742210e-02 -1.33715048e-01 -1.14422716e-01 -3.30459386e-01
#   2.58276439e+00 -5.23877107e-02  1.77708805e-01  1.88008264e-01
#  -9.35248658e-02 -5.57439961e-02  5.96068762e-02 -8.78379568e-02
#   1.30679607e-01 -5.28724827e-02 -1.81964681e-01 -8.77108276e-02
#  -1.71470499e+00  3.67643416e-01 -1.98727056e-01 -1.43896806e+00
#  -3.79491001e-01  1.06617417e-02 -6.47128969e-02 -6.86856270e-01
#  -1.71109699e-02 -5.53997420e-02 -8.24979246e-02 -7.29270935e-01
#  -8.67691040e-02  3.31719428e-01  6.18912801e-02  5.57057280e-03
#  -1.28638014e-01 -2.72921532e-01 -8.54996145e-02 -6.65099993e-02
#  -2.98860282e-01 -1.27329230e-01 -2.77561128e-01 -2.00722814e-01
#  -6.50728568e-02 -1.92887202e-01 -5.89321181e-02 -9.12778676e-02
#  -1.48190761e+00 -8.84317532e-02 -2.18279734e-01 -1.50156766e-01
#  -1.70834452e-01  9.42027569e-02  2.47608423e-01  1.24524646e-02
#  -6.23135716e-02 -1.10620208e-01 -8.14289898e-02 -2.99377769e-01
#  -8.96609575e-02 -2.77503937e-01 -1.07639663e-01 -1.55557528e-01
#  -2.72688810e-02 -8.62973183e-02 -1.09931804e-01  4.89431530e-01
#  -1.48759382e-02 -1.37492895e-01 -1.29035801e-01 -4.56201375e-01
#  -2.08801460e-02 -4.62263934e-02 -2.00581830e-02  3.73742253e-01
#  -4.73067947e-02 -6.26353547e-02 -1.49246737e-01 -1.22787207e-01
#  -2.57399112e-01  1.60308540e-01 -1.37570396e-01 -4.32804793e-01
#  -4.13859822e-02 -2.38885999e+00  6.71324283e-02  6.58020228e-02
#  -8.42810869e-02 -1.09754339e-01  2.96083474e+00 -2.77136475e-01
#  -1.99120324e-02 -2.91503608e-01  5.23801863e-01  2.15555772e-01
#  -1.26689553e-01 -6.29267469e-02 -1.47345617e-01 -1.94265902e+00]
# tensor_name:  TemporalFusionTransformer/layer_normalization_20/gamma
# [ 3.64744812e-01  9.05640572e-02  7.83126533e-01  8.91015172e-01
#   2.05157831e-01  2.66328752e-01  4.98411119e-01  5.10548413e-01
#   7.27355123e-01  1.08710408e+00  3.59379530e-01  8.57326090e-01
#   8.57891500e-01  6.69195354e-01  6.63104057e-01  3.82515907e-01
#   7.60737419e-01  4.06934619e-01  1.23434806e+00  1.69627741e-01
#   1.07757664e+00  9.87082005e-01  3.66581440e-01  5.28897643e-01
#   2.49776393e-01  1.26252604e+00  1.08381808e+00  1.19443929e+00
#   5.39329767e-01  6.15416765e-01  5.43057680e-01  1.88719296e+00
#   7.84550428e-01  5.23684382e-01  9.25093114e-01  4.69602108e-01
#   4.84068543e-01  6.00914955e-01  5.48621595e-01  1.58380821e-01
#   1.85916615e+00 -1.37329981e-01  6.53299451e-01  2.80831909e+00
#   5.65533400e-01  8.34929943e-01  3.87687147e-01  4.90226634e-02
#   4.71008003e-01  8.36730778e-01  3.34543884e-01  7.28518486e-01
#   2.07712665e-01  1.25058681e-01  9.79250789e-01  3.20823252e-01
#   4.67001796e-01  6.36667479e-04  8.23339343e-01  2.93403894e-01
#   1.45728338e+00  1.42762434e+00  9.86542583e-01  2.04551053e+00
#   8.28553140e-01 -1.98378097e-02 -2.55239755e-01  8.49458516e-01
#   2.60279155e+00  4.18220162e-01  1.91091108e+00  6.12514079e-01
#   7.88146019e-01  5.27030230e-01  8.64708304e-01  3.10477543e+00
#   6.08155169e-02  4.51610982e-01  7.65115619e-01  4.74592671e-04
#   9.30032492e-01  1.17175472e+00 -8.29520077e-02  5.20893395e-01
#   2.74704933e-01  1.70919091e-01 -1.03732646e-01  1.16120470e+00
#  -1.03115223e-01  7.44649529e-01  7.22189546e-01  2.32046318e+00
#   9.79533613e-01  6.49267793e-01  5.39443910e-01  5.89712441e-01
#   3.49463560e-02  8.14423382e-01  6.53432548e-01  5.02436519e-01
#   2.06538224e+00 -1.09236225e-01  2.51224607e-01  1.06940341e+00
#   3.18994075e-01  9.13057029e-01  7.25885212e-01  1.64182171e-01
#   1.27918589e+00  1.22766578e+00  3.92904371e-01  4.50946540e-01
#   1.03291583e+00  2.79145449e-01  7.54846752e-01  4.19059187e-01
#   8.33743438e-02  5.97170770e-01 -3.40932637e-01  2.27020097e+00
#   1.47386277e-02  5.90718687e-02  4.82912838e-01  8.17587435e-01
#   6.02494955e-01  5.74550331e-02 -2.30897114e-01  5.97215712e-01
#   1.05968475e+00  5.50494492e-01  1.08169746e+00 -3.57804567e-01
#   5.07558942e-01  8.76901925e-01  1.15972328e+00 -1.86010357e-03
#   7.56613016e-01  5.78512728e-01  5.32135405e-02  8.56860459e-01
#   4.58822548e-02  1.97366762e+00  1.92939401e-01  2.25013471e+00
#   9.69084024e-01  1.33616257e+00  2.86820352e-01  3.04819673e-01
#   1.04436564e+00  9.15805876e-01  4.21681833e+00  1.28431249e+00
#   7.83140421e-01  6.04680002e-01  6.80541635e-01  3.77280444e-01
#   4.87230092e-01  6.26313806e-01  5.47657013e-01  1.31080198e+00]
# tensor_name:  TemporalFusionTransformer/layer_normalization_21/beta
# [ 4.39638924e-03  8.50333720e-02  1.24177011e-02 -9.15696770e-02
#   5.55741079e-02  7.47205392e-02 -5.88089414e-02 -2.26789284e-02
#   1.30330339e-01  6.59101009e-02 -6.68694451e-02 -2.08332334e-02
#  -1.50390506e-01 -6.49033859e-02 -8.69387388e-03  1.22114696e-04
#  -1.87792834e-02 -1.01805486e-01 -4.13281135e-02  6.53104037e-02
#  -3.43095176e-02  4.32076119e-02  9.60788410e-03 -6.36602119e-02
#   2.81687547e-02  3.74442451e-02  9.47995558e-02  1.44286612e-02
#   1.19408127e-02  8.64108205e-02 -3.35560460e-03  5.89687154e-02
#  -9.23606083e-02  3.86315435e-02 -1.50160685e-01  8.15964714e-02
#  -1.31531343e-01 -7.92672783e-02 -5.49860038e-02  3.67021747e-02
#   1.32628888e-01  1.05892293e-01  8.64767283e-02  2.23211497e-02
#   6.58791810e-02 -2.83638239e-02 -1.16257612e-02 -7.08228499e-02
#   3.58775556e-02 -1.41731858e-01 -9.43261012e-03  1.02093350e-02
#   7.86381885e-02 -1.03461884e-01  4.72237393e-02 -3.62528376e-02
#   1.04808949e-01 -2.68876422e-02 -8.02435055e-02 -1.30431831e-01
#  -4.68791611e-02 -7.21701160e-02 -3.00332531e-02 -1.16777159e-02
#   1.79554448e-02 -2.79683042e-02 -7.46367723e-02  4.40367311e-02
#   5.73890209e-02  2.64437273e-02  5.98862916e-02  7.46037215e-02
#   1.09368891e-01 -8.42588991e-02 -9.23682153e-02  3.07872295e-02
#   9.75507423e-02 -6.09578378e-03 -1.38110369e-02 -8.45905300e-03
#  -1.09905656e-02  1.60046387e-02 -8.14944878e-02 -1.23691373e-02
#   1.14151806e-01  1.86921679e-03 -8.22825581e-02 -6.10519275e-02
#   8.37614238e-02 -5.70844896e-02  1.74501701e-03 -8.75032693e-02
#   2.27119327e-02 -1.23094730e-01 -6.53178841e-02 -3.40841361e-03
#  -2.12999899e-02  5.87222688e-02 -1.04032941e-01  7.69622158e-03
#   7.12681562e-02  1.59393232e-02  3.89926508e-02  7.28584006e-02
#   3.36171053e-02  6.45912215e-02 -1.01320691e-01  9.79667976e-02
#  -2.86261234e-02 -9.60397907e-03  6.79552406e-02  9.94574800e-02
#  -5.70346974e-03 -2.15252917e-02  8.49040896e-02  4.37918417e-02
#   4.62578190e-03  5.50662652e-02  7.27137402e-02 -7.64097795e-02
#  -3.28026377e-02  8.91724415e-03 -3.80947478e-02 -7.72932246e-02
#  -8.79425649e-03  2.09342763e-02 -1.10324375e-01  3.05684656e-02
#  -1.13715101e-02 -8.41765106e-03 -4.50720871e-03 -8.36854205e-02
#  -2.08017905e-03  6.89127371e-02 -9.55493972e-02 -5.79990931e-02
#  -8.49197954e-02 -3.08516882e-02 -9.61724818e-02  9.94332973e-03
#   6.78369552e-02  4.74921763e-02  1.03413075e-01  2.41695270e-02
#   5.71062192e-02  3.41697745e-02 -9.75307375e-02 -4.67245094e-02
#  -5.58492765e-02 -2.57611927e-02  9.34181884e-02  1.23222703e-02
#   3.93918641e-02 -6.66492432e-02 -1.10621173e-02  3.76617201e-02
#  -6.10446893e-02 -2.75425520e-02  7.18934685e-02 -6.26184642e-02]
# tensor_name:  TemporalFusionTransformer/layer_normalization_21/gamma
# [0.9966285  1.0312653  0.91856366 0.99379164 1.0154579  0.9726992
#  0.94954574 0.90075237 1.1046108  1.0664108  0.8922946  0.9747615
#  1.0749815  1.0081224  0.93534166 0.98595953 0.9761762  1.163857
#  1.0118577  0.9776107  0.9806377  1.0240946  1.0216578  0.8919264
#  1.0078999  0.9793274  1.0137807  0.9945982  1.0507716  1.030415
#  0.93495756 0.99013585 1.0431471  0.98443544 1.0789264  0.99051654
#  0.97057325 0.98320633 0.8842439  0.9340912  1.0663587  1.0607961
#  0.9270094  0.8965741  1.0097241  0.8884142  1.009036   1.0391476
#  1.0361941  1.156257   0.95433044 1.0223475  1.0747149  0.8790136
#  1.1013304  0.99116564 1.0533051  0.97024655 0.97215724 0.9917417
#  1.0625515  1.0212324  0.9309594  1.0296583  0.97352576 0.8952335
#  1.0559013  0.89984906 0.8840956  1.038117   1.0921978  1.0056345
#  1.1246302  1.074914   0.9313014  1.0023637  1.0038861  0.87714785
#  0.97593933 1.0358344  1.0331272  1.023789   0.9510916  0.94959736
#  1.0289164  1.0729059  1.0050781  0.9870353  1.1370275  0.9710035
#  0.91503024 1.0028863  1.00037    1.0043964  0.9511344  0.953731
#  1.0051528  0.9333202  1.0218462  0.97464496 0.9918167  0.9426852
#  0.9777616  1.0554014  0.8997903  1.0305381  0.96627754 0.92702
#  0.88654727 0.88934356 0.9677969  1.0711708  1.0410802  1.0711284
#  1.0976307  0.9699017  0.93643194 1.0295962  1.0068662  0.92203426
#  1.0007173  0.9532535  0.90770686 0.9872216  0.9440825  0.8519833
#  0.9546726  0.9167885  0.8930013  1.060055   0.8661467  0.98085487
#  0.95540315 0.96959245 1.0511565  1.0157259  0.97525615 0.9196292
#  0.9598125  0.90216225 0.91933143 0.9108726  1.1080307  0.9603269
#  1.1733127  1.0286207  1.0212989  0.91800195 0.9142006  0.9594297
#  1.0295496  0.9159181  0.9504237  1.1024157  1.0021898  1.0533922
#  0.98868406 0.9972677  0.95508283 1.0884013 ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_22/beta
# [-1.21363988e-02  1.11466072e-01 -3.61948274e-03 -4.31152433e-02
#   2.35551149e-02  9.20319259e-02  2.41923612e-02 -8.38373825e-02
#   1.51337415e-01  9.96317640e-02 -6.54675364e-02  2.80750133e-02
#  -1.48156002e-01 -9.83806923e-02  4.54354733e-02  4.18711081e-03
#   5.93051836e-02 -9.90461186e-02 -5.87331615e-02  3.69413458e-02
#  -3.12368348e-02  7.99445435e-02 -1.24160759e-02 -4.89310548e-02
#  -5.85491471e-02  5.32249622e-02  6.75881952e-02  2.10969616e-02
#  -1.32418092e-04  8.59009027e-02 -5.70796663e-03  6.23197183e-02
#  -9.18280929e-02  3.71706188e-02 -6.17687106e-02  1.28622413e-01
#  -1.39388189e-01 -8.07949975e-02 -1.47682875e-01  4.02056314e-02
#   1.13299966e-01  4.04805392e-02  6.87948465e-02 -4.03029956e-02
#   1.18110158e-01 -2.08376609e-02  3.70666496e-02 -3.83304171e-02
#   1.62652522e-01 -1.29033417e-01  5.43976203e-03  3.94069627e-02
#  -1.99255496e-02 -1.30008712e-01 -2.45907847e-02 -8.80246237e-02
#   1.57458663e-01 -1.60044041e-02 -5.13609871e-02 -9.15684178e-02
#  -9.45683271e-02  5.26567874e-03 -3.92531641e-02 -2.86069512e-02
#   5.81282564e-02 -6.02456704e-02 -6.38152584e-02  8.57168138e-02
#   1.96039248e-02  7.61692747e-02  9.38259661e-02  1.31640390e-01
#   7.56601021e-02 -1.16631068e-01 -3.24052572e-02 -1.86273176e-02
#   2.35792361e-02  1.97584135e-03  2.25143321e-02 -5.25460877e-02
#  -1.76896323e-02 -4.99857664e-02 -1.02428176e-01  3.89965507e-03
#   9.09650102e-02  9.61124822e-02 -6.96312115e-02 -6.10255711e-02
#   4.01754193e-02 -5.88816404e-02  1.12311272e-02 -1.41653111e-02
#  -4.57393788e-02 -7.65985847e-02 -1.27754077e-01  6.54642880e-02
#   2.15848647e-02  6.56605810e-02 -8.63009691e-02 -3.75141054e-02
#   7.48071447e-02 -8.40766728e-02  8.57882723e-02  1.20387807e-01
#   2.76324619e-02  1.06215291e-01 -1.22467235e-01  5.22508584e-02
#  -6.26221374e-02 -6.51334524e-02  1.12714447e-01  1.03994533e-02
#  -5.17846160e-02  6.62195534e-02  1.16975633e-02 -4.10952345e-02
#   4.48435359e-02  1.45157455e-02  3.65953930e-02 -1.59004658e-01
#  -1.25621364e-01  4.91906181e-02  7.81908166e-03 -1.06902152e-01
#  -8.42123404e-02  1.63932517e-02 -3.44059393e-02  1.11457981e-01
#   2.19628960e-02  4.39302102e-02  6.49538413e-02 -1.27278447e-01
#  -6.30562454e-02  3.32632065e-02 -1.58189699e-01 -6.11107871e-02
#  -1.07969671e-01 -9.55069961e-04 -2.32107602e-02  3.40535045e-02
#   8.49453136e-02  2.92576496e-02  3.58784683e-02 -1.33364825e-02
#   9.53282937e-02 -6.44915104e-02 -1.49128124e-01 -1.02874301e-01
#  -6.81274757e-02 -3.63793522e-02  1.77288577e-01 -1.53801439e-03
#   4.13367152e-02 -5.05009703e-02 -1.11734793e-02 -1.29517941e-02
#  -1.49049133e-03 -3.37484963e-02  7.42987990e-02 -1.21916443e-01]
# tensor_name:  TemporalFusionTransformer/layer_normalization_22/gamma
# [0.97029483 1.0248232  0.95629716 0.9409622  0.9907877  1.0139332
#  0.9113254  0.9082097  1.1072475  1.061718   0.8756231  1.0305903
#  1.0976312  0.97853863 0.94424075 0.9948995  0.92205787 1.1409458
#  0.99604756 1.0033796  0.93527544 1.0447465  1.023032   0.9261395
#  1.0453309  0.93819296 1.0260937  0.99639183 0.9216502  0.9939422
#  1.0155195  0.984486   1.0700692  1.0196443  1.0122294  0.93348235
#  0.96953243 1.0264391  1.0427333  0.90751845 1.0132048  0.9682294
#  1.0226657  1.0013423  1.0292706  0.9143796  1.0540652  1.0092424
#  1.0542263  1.154184   0.97439796 1.0694677  0.9797372  1.027163
#  1.0314164  1.0174522  1.0839446  0.9340221  0.93062615 0.9430173
#  1.06501    0.97261053 1.0027777  0.95149976 0.966308   0.9957298
#  1.0068607  0.9496741  0.90804684 1.0228232  1.0583571  1.0169626
#  1.0432153  1.0864185  0.92648727 1.0190687  0.9712922  0.9536671
#  0.98275137 0.98390234 0.96080244 0.9900403  1.0305781  0.9531011
#  1.0123887  1.0311844  1.0240297  1.0023067  1.0647112  1.0083047
#  0.9782062  0.9733368  1.0181699  1.0357176  0.97568643 0.91568303
#  1.0012153  0.9597557  1.0745618  0.9477599  0.92597747 0.9464936
#  0.97033495 1.0495486  0.9312494  1.0783281  0.9802873  0.91723275
#  0.99788624 0.9626899  1.0422059  0.9430161  1.0580684  0.975338
#  0.99568486 1.0427408  0.9515044  0.9348552  0.9682886  1.0864468
#  1.0241838  1.0454168  0.93489784 1.0771023  1.0103084  0.9406781
#  1.0153489  1.0323145  0.9437628  1.000377   0.92390364 1.0711485
#  0.970972   0.9338441  1.0917656  0.9862471  1.0414002  0.9311031
#  0.9462343  0.9062206  1.0050235  0.9539299  1.0080441  0.9554389
#  1.0878888  1.0300448  1.0567132  0.9939949  0.951336   0.9340357
#  1.1878462  0.9634617  0.9539611  0.99055886 0.93338054 1.0146658
#  1.0214962  0.99544555 0.9381191  1.0680058 ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_23/beta
# [-6.7394665e-03  2.1593619e-02 -4.6921009e-01 -3.1728935e-03
#   5.8400626e-03  2.0880138e-03  3.5319876e-02 -5.2280491e-03
#   1.6086662e+00 -5.0675292e-03 -2.3799552e-02  9.4414645e-01
#  -1.1434934e-02 -2.2729794e-02 -1.0790067e+00 -1.4323094e-02
#  -4.0017134e-03 -7.1509826e-01  1.0710038e-03  1.9659119e-02
#  -7.4386538e-04 -9.8273996e-03 -2.0814962e-03 -1.6089536e-02
#  -1.4005325e-02 -9.9484015e-01  4.8500937e-01  4.0431442e-03
#  -1.8283356e-02 -7.8027528e-03 -3.0736227e-03 -1.9778242e-02
#  -1.9740516e-03 -2.0402525e-02  5.8653248e-03  3.7336390e-02
#  -1.4505166e+00 -7.5356579e-01 -1.3550322e+00 -1.3320277e-02
#  -1.6225160e-03  4.3493083e-01  1.3378264e-02 -1.2526953e+00
#  -1.2894159e-02 -2.4488340e-03 -2.8787546e-03 -1.8046696e-02
#   1.4072831e+00 -4.1797596e-01  6.3010827e-03  8.6195196e-04
#   4.6637105e-03 -1.1625111e+00  2.3388050e-03 -1.8942140e-02
#  -1.3490542e-02  4.9683391e-03  1.0208732e-02 -9.6613777e-01
#  -4.9832826e-03  5.5250288e-03 -5.3882849e-01 -1.9223643e-02
#   1.2108875e-02 -7.1480083e-03  2.0216582e-03 -1.2318630e-02
#  -1.3750378e-02  5.6756508e-01 -1.8707670e-02  1.3291348e+00
#  -1.0302585e-02 -3.3831587e-01 -8.4126543e-04 -6.0594040e-03
#  -1.4430057e-02  3.4501620e-03  1.0302341e-02 -4.8367549e-03
#  -1.1583608e-02 -2.9434625e-03  3.1612717e-02 -2.1955999e-02
#  -2.0230122e-02 -1.2260576e-02 -2.1895962e-03 -1.6598207e+00
#  -1.3863727e-02  2.2795884e-04 -1.6864441e-02 -1.5684340e-02
#  -8.2391296e-03  8.2156882e-03  3.6894199e-02  1.3121771e-02
#  -1.8026335e-02  8.4229636e-01 -7.1705692e-03 -9.4238715e-03
#   1.4907552e+00 -1.1206873e-02  1.2119898e+00  1.3957398e+00
#  -1.5576884e-02  7.0931256e-02 -3.0119189e-03 -1.7381212e-02
#  -1.3085690e-02 -2.0401778e-02  2.7643636e-01  3.5038620e-04
#  -2.0648263e-02 -1.9908687e-02 -4.4472306e-03 -7.3837368e-03
#  -2.0702206e-02 -6.3808192e-03 -1.4899074e-02 -8.3229877e-03
#  -1.5593580e-02 -7.5464947e-03 -2.5732157e-01 -1.3215944e+00
#  -1.2607307e-02  1.7652456e-02  7.7105602e-03 -1.1155642e-02
#  -8.5111469e-01 -1.8266538e-02  4.5730788e-02 -4.9210849e-01
#  -1.2152919e-02 -1.6161954e-02 -1.5370598e+00 -1.2826906e-03
#  -2.0162970e-02  2.0313529e-02 -1.4686221e-02 -1.5906626e-02
#  -3.5114998e-03 -6.5062228e-03 -1.7728612e-02  9.4117081e-01
#  -1.3621867e-02 -1.6043101e-02 -1.0110836e+00 -1.4506466e+00
#   8.5072443e-03 -3.2811104e-03  1.4550452e+00  1.7944999e-02
#   1.5240268e+00 -1.4217704e-02 -1.4772360e-02 -3.7921950e-02
#  -1.6766371e-02 -4.5255353e-03  3.4325495e-02 -1.3127445e-02]
# tensor_name:  TemporalFusionTransformer/layer_normalization_23/gamma
# [-2.56070346e-01 -1.02774866e-01 -6.24924339e-03 -1.87117398e-01
#   3.18244696e-01  5.54766059e-02  5.34523368e-01  9.57912877e-02
#   1.25780153e+00 -1.17012717e-01 -2.63149470e-01  1.54193327e-01
#   3.50352049e-01 -3.73939425e-01  3.70723635e-01  2.39321753e-01
#  -6.52626231e-02 -9.89605486e-03  3.66994917e-01 -5.60289435e-02
#  -1.17870964e-01 -1.50130108e-01  2.38412991e-01  1.69261843e-01
#  -1.96539864e-01  1.69347942e-01 -7.78005039e-03  6.30603880e-02
#  -2.77421981e-01  3.13724548e-01 -1.07086273e-02 -4.97766919e-02
#   8.43509287e-02  3.73145342e-02  3.05269808e-02 -1.31329857e-02
#   8.38621199e-01  1.09626632e-02  5.97312391e-01 -3.77032459e-02
#   5.42883798e-02 -1.17082102e-02  6.81407228e-02  5.96090794e-01
#   6.01819009e-02  2.88929492e-01 -5.10116182e-02  1.60888314e-01
#   7.25537717e-01 -3.04908957e-03 -4.00961414e-02 -3.87603998e-01
#   2.72834022e-02  3.51291895e-01 -3.14427525e-01  3.97188902e-01
#   2.46188372e-01  6.08404428e-02  2.00217947e-01  7.44529590e-02
#   1.32997423e-01 -3.68729979e-02 -2.68382058e-02 -2.41210103e-01
#   1.34867832e-01 -1.47488654e-01 -2.31434122e-01  7.41337091e-02
#   2.93409973e-01 -1.49596222e-02  5.19219398e-01  6.65279150e-01
#   3.88499081e-01  4.78519499e-02  1.34417117e-01 -2.69028507e-02
#  -1.69207677e-01 -5.71658790e-01  1.78044774e-02 -2.55905837e-01
#  -1.29608482e-01 -2.62745768e-01  1.00440860e+00 -2.25153491e-02
#   1.29112437e-01 -2.70572096e-01 -2.51262307e-01  1.15652454e+00
#   4.42072935e-02  2.50684410e-01  3.65640707e-02  1.72266811e-01
#   4.54296261e-01  1.83182999e-01 -5.61573245e-02 -5.68284504e-02
#   2.63416052e-01 -4.26682527e-04 -2.42726862e-01 -4.81361419e-01
#   1.01731396e+00 -1.80059195e-01  4.20749277e-01  7.33504295e-01
#   4.37368572e-01 -5.74210696e-02  3.46005380e-01  3.73762369e-01
#  -8.19567069e-02 -2.48436376e-01 -4.46181707e-02  1.85061786e-02
#  -2.66105711e-01 -5.14036641e-02 -1.05761543e-01 -1.87525600e-01
#  -4.33952540e-01  3.33976895e-01  5.79229712e-01  3.82494241e-01
#  -3.32185000e-01  1.76755965e-01 -1.16039638e-03  6.90036595e-01
#  -2.34933794e-01 -2.17113979e-02 -4.21751469e-01 -8.98111314e-02
#   3.76390815e-02 -4.16831285e-01  2.75306664e-02 -3.07543427e-02
#  -1.12178616e-01  2.88742423e-01  1.08483279e+00 -1.34193078e-01
#   1.97339714e-01 -1.68737769e-02  3.78786117e-01 -2.54141510e-01
#  -2.55669028e-01 -2.30556011e-01  2.49150664e-01  4.26245593e-02
#   3.27229381e-01 -3.13752204e-01  2.02043638e-01  8.90151083e-01
#   2.38989154e-03 -1.04458652e-01  1.00081682e+00  2.10858546e-02
#   9.80393469e-01  1.27340302e-01  2.05552340e-01 -2.47815654e-01
#  -7.25490972e-02  5.46267629e-02 -9.71147865e-02 -5.97904017e-03]
# tensor_name:  TemporalFusionTransformer/layer_normalization_24/beta
# [-5.6719505e-03 -3.3358764e-02 -3.3369663e-03 -6.8484694e-03
#   2.5769034e-03  8.0812303e-03 -1.2004279e-03  1.8418288e-04
#  -1.4985792e-02 -4.6742713e-01  7.3863659e-04  1.1639616e-03
#  -1.6213618e-02 -4.1569732e-02 -3.3809543e-03  3.7933397e-04
#  -3.4544063e-03  3.9925543e-03  3.7526279e-03  6.1578839e-03
#   9.2417225e-03 -4.0139360e-03  8.3386442e-03 -1.4209442e-02
#  -1.1257373e-02 -1.0642114e-03 -2.4425481e-02 -1.2120029e-02
#  -1.7737577e-03  2.1061802e-02  3.2949261e-05  3.0930970e-02
#   7.8888843e-04 -2.9701791e-03 -2.4125897e-03 -1.0416897e-02
#  -2.8582104e-03  1.3582595e-02 -1.5679314e-03 -1.7857209e-02
#  -4.4321018e-01 -5.1206164e-03  4.4429135e-03  1.7169902e+00
#  -2.4985638e-03 -3.0932850e-03 -1.0898324e-02  8.1794662e-04
#  -2.0466759e-03 -4.2386334e-03 -4.5479424e-02 -9.6945900e-01
#  -8.6173258e-04 -1.0220387e-03 -5.0889179e-03 -2.1559585e-02
#  -6.7531117e-03  7.0242665e-04 -7.3493468e-03 -3.6765421e-03
#   1.1224390e-01 -4.1321024e-02  6.0989941e-04 -9.5338866e-02
#   7.5319842e-03  1.2654020e-03  1.8452143e-03 -1.0362231e-02
#  -8.9742142e-01 -2.6569674e-03  1.7500967e-01  7.5355391e-03
#  -2.4922551e-03 -9.5323252e-05 -5.9081214e-03  2.0501504e-02
#  -2.1894220e-03 -1.4845977e-02 -1.1960398e-03  5.6648264e-03
#   5.0328994e-01  5.0667105e-03 -1.8752739e-03  6.6817924e-02
#  -5.6831650e-03  3.0145631e-04 -3.8151909e-04  5.3780431e-01
#   4.1466295e-03 -2.4458384e-03 -1.5482635e-03  1.6976486e-01
#   1.3890343e-03 -2.4587166e-02 -1.0179949e-03 -1.7057223e-03
#   8.7357068e-04  2.1405594e-01 -1.4224644e-03  2.5875226e-02
#  -1.2492670e-01  3.2454948e-03  5.6522684e-03 -9.5182210e-03
#  -6.7712860e-03 -2.6247079e-02  1.1117350e-02 -6.0347090e-03
#   5.9949011e-01  3.2461587e-02  9.6270386e-03  7.1402797e-03
#   1.0099102e-02  7.8212668e-04  3.3547651e-02 -1.5836751e-02
#   1.1419371e-04  4.1218870e-03 -5.5121118e-03  8.8792980e-02
#  -3.4976704e-03 -2.2102222e-03  6.1645880e-03 -7.6668226e-04
#   1.6549242e-03  2.4823574e-03 -2.1755339e-03 -3.1397622e-02
#   6.0642599e-03  2.1294171e-03 -7.9645813e-03  1.1480169e-02
#   2.3131184e-03 -6.4560100e-03  7.1968082e-03 -3.5002816e-02
#   1.7918134e-04  5.7614045e-03 -2.2552689e-03  6.0788778e-05
#   1.8238558e-02  1.1591628e-02 -1.6687654e-02  1.3970673e-01
#   3.6238804e-03  2.0751770e-01  1.4758715e-03 -2.3367628e-03
#  -9.8876031e-03 -1.5482251e-03 -1.5543293e+00 -3.5738060e-03
#   4.4120550e-03  3.4996951e-03 -2.5167592e-02 -3.6672642e-03
#  -2.4256348e-03 -7.8383377e-03 -4.9574431e-03  5.7851958e-01]
# tensor_name:  TemporalFusionTransformer/layer_normalization_24/gamma
# [ 0.13572443  0.4008731   0.04413545  0.05874157 -0.26790687  0.1709852
#   0.00463825 -0.01831946  0.39374653  1.1119796   0.08520687  0.10669296
#  -0.0412179   0.1977789  -0.02366247 -0.00343897  0.19951618 -0.04829196
#   0.37577888  0.13095963 -0.13985375 -0.08462854 -0.04926538  0.06402133
#   0.00565395  0.08644664  0.54378486  0.10406151  0.01178433 -0.13502698
#  -0.09454323  0.7060818   0.03508998 -0.01832001 -0.08584145  0.14158368
#   0.13021283  0.06454939  0.04293182 -0.02540648  0.86454344  0.18078263
#   0.04859978  0.28833684 -0.01661046  0.0719145   0.07227551 -0.08329591
#  -0.07008348  0.05530644  0.5141735   0.48597202  0.00647425 -0.00531651
#   0.07049165  0.19623093 -0.03733353  0.05837793  0.03603304  0.06493819
#   0.81661904  1.031       0.13876837  0.7836612  -0.16407384 -0.04562711
#  -0.10112302  0.1580543   0.18302448  0.113517    1.1308026  -0.35433257
#  -0.03584246 -0.00377054  0.11384147  1.7910845   0.01133152 -0.01689954
#   0.11247402 -0.01496234  0.34633845  0.7400747   0.04798615  0.81343603
#   0.32867187  0.01201459 -0.05580422  0.2607413  -0.0579939   0.12399895
#   0.05328988  1.3774918  -0.05157471  0.3268641   0.03425553 -0.04256373
#  -0.02409976  1.0446523   0.0830169   0.14539722  1.1051362  -0.01769947
#  -0.11347308  0.59355086 -0.01570925  0.65196466  0.13419315  0.06988466
#   0.29585975  0.62476605  0.05849753 -0.23338123 -0.19319318 -0.01243892
#  -0.06046154 -0.08626519 -0.02747366 -0.11077167 -0.16181563  1.4856683
#   0.09781069 -0.0081023  -0.02926549 -0.03088339 -0.04546918 -0.01924518
#   0.11848458  0.42879096 -0.04962904  0.02998585  0.3254051  -0.09902401
#  -0.08529191 -0.48281956  0.5560645   0.4554749  -0.01962125 -0.09421676
#   0.06847285  0.00449787 -0.01938003  1.2849655  -0.04386235  2.2994776
#  -0.00858767  0.55617726 -0.06362487  0.04486085  0.54365796 -0.04835089
#   0.17738783  0.26974696 -0.08274119 -0.4158666   0.30456275  0.10036553
#  -0.04270167  0.19103307  0.07883654  0.2248792 ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_3/beta
# [-0.03727459 -0.0715299   0.07237162  0.00251461  0.10714868  0.12182339
#  -0.10838793  0.11168345 -0.12017047  0.01287585  0.12971106  0.01660349
#   0.08928609  0.04692388  0.04869653 -0.02887418 -0.10336439 -0.02965091
#   0.03211367  0.10384673 -0.10848874  0.11508834 -0.11231339  0.05894936
#   0.13229236 -0.0494878   0.05222864  0.06685691 -0.02566066 -0.101099
#  -0.02081877  0.0162852  -0.02160704 -0.1343528   0.12691247  0.02871559
#   0.07277376 -0.05735727 -0.01543625 -0.01680073  0.03747765  0.06291287
#  -0.00863785  0.05028123  0.01795268  0.10295492 -0.06336145  0.14740708
#  -0.1228052  -0.0986492  -0.0247271   0.048644    0.0321199   0.10525957
#   0.05682088 -0.03186198  0.00017897 -0.12923306 -0.04331469  0.00080538
#   0.00431728 -0.0496667   0.06792192 -0.01687619 -0.05868609  0.07035947
#  -0.12224446  0.0862764   0.11736575 -0.14023234  0.06319746  0.11235023
#   0.0537536  -0.07791727 -0.00935887  0.02812774  0.06548729 -0.00423174
#  -0.05319512 -0.07372285  0.00959106 -0.09271253  0.07983801  0.03156195
#   0.01293814 -0.02223851 -0.03446534 -0.07420292 -0.06407115  0.02092326
#   0.05123202 -0.02466384  0.05208761 -0.0741202   0.08553988 -0.11935657
#  -0.11929245 -0.01077484  0.06118912 -0.10326084 -0.02508141  0.01867767
#  -0.03969627 -0.10727599  0.06345809 -0.04309682  0.10341906 -0.13637029
#  -0.07392164 -0.00045526 -0.04774447 -0.10082981  0.06491859  0.03465815
#  -0.05579444  0.12549764  0.12121338  0.0422841  -0.09128962 -0.06366284
#   0.07681263  0.1112239   0.11543326 -0.07499938  0.08026656 -0.08434438
#  -0.0642821  -0.03922524 -0.02752965  0.03752703 -0.06841106 -0.07875179
#  -0.03645149 -0.06542674  0.09770824  0.11422686  0.01679575  0.00590803
#   0.01426268  0.00216671 -0.03714926  0.07302561 -0.0189112   0.00388036
#  -0.0020673  -0.07891107  0.05940192  0.03793587 -0.00155604  0.05860781
#  -0.1176549   0.05258835  0.04160287 -0.00225593 -0.06265355 -0.07113979
#  -0.02680555  0.08696909 -0.08444522  0.11826438]
# tensor_name:  TemporalFusionTransformer/layer_normalization_3/gamma
# [0.9710492  1.0098646  1.0121748  0.8828674  1.0073054  1.05344
#  1.0193648  0.9944333  1.0523701  1.0578363  1.1113816  0.9296131
#  0.95224124 0.9146195  0.97512263 0.9195501  0.97572887 0.9691442
#  0.94654644 0.98118824 1.0299038  1.0353644  0.97545314 0.9351343
#  1.0936828  0.9068237  0.94833684 1.0489951  0.9992278  1.0216163
#  0.9308931  0.8751027  0.9574283  1.107486   1.0504552  0.92791545
#  1.0062374  0.9834737  0.88864887 0.95694095 0.9127026  0.94290406
#  0.95473105 1.0012709  0.9884121  0.946748   0.87612945 1.0996314
#  0.94390523 0.94431067 0.99139714 0.9603269  0.90890825 0.98820674
#  0.98993605 1.043608   0.9301908  1.0775691  0.9268253  0.889154
#  0.98033077 0.95094156 0.98114884 1.0030601  0.93871844 1.0249753
#  1.1130674  1.0161675  1.0054663  1.09232    0.9882518  1.053662
#  0.97833455 1.0123656  1.010083   0.94527936 0.9643397  1.021867
#  0.9221034  0.99937755 0.9924384  0.98326427 0.9753342  0.9133944
#  0.99721515 0.9534129  0.96581036 0.88921374 1.0040702  0.8880738
#  0.9130292  1.0273707  0.9544093  0.98916566 0.9459178  1.0245291
#  1.0641137  1.0072459  0.9442075  1.0881903  1.0145198  0.91196877
#  0.9483533  1.0855392  0.9316144  0.9871276  1.0348897  1.0407047
#  1.0204126  0.89531845 0.9516754  0.9784916  0.9471432  1.0265734
#  1.0674192  1.0492915  1.000225   0.98174196 0.90077376 0.9788208
#  0.9851148  0.9825633  0.95853555 1.0145894  0.9755853  0.9467451
#  0.8929326  0.97732705 0.9952512  1.0180113  0.996899   0.9530435
#  1.0260601  0.923738   1.0048598  1.0542859  0.9072358  0.90680814
#  1.0527523  1.0332791  0.9522951  0.94051236 0.93955016 0.97072387
#  1.0079995  0.9612022  0.9627932  0.95534146 0.9917038  1.0007174
#  1.0660747  0.94243544 0.9942134  0.9265346  0.9189306  0.910048
#  0.8802579  0.966427   0.9136183  1.026777  ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_4/beta
# [-0.19000088 -0.08772769 -1.6280354  -0.57739836  2.3415854  -1.865302
#   0.8143772   0.64298457  1.3396686   0.89221495  1.2410003   0.8090826
#   0.11430614 -0.39170766  0.01135138 -1.1340919   0.7066124  -1.3663622
#  -1.038549   -1.0595813  -0.4789591   0.70263106 -0.9025753   0.74193764
#  -1.595085    0.7521156  -1.2661276  -1.5504515   0.39301857  0.01131724
#   1.6407094   0.10761314 -1.0432494   0.6462171   0.15311109  0.1483184
#  -0.30287644  0.44753665  1.138832    0.6222665   0.43049118 -1.6388462
#  -0.10750389 -0.06124096 -0.1584121  -0.8858586  -0.9619653   0.22146209
#   1.4253483   1.5121177   0.20111105 -1.0515845  -0.92851704  0.45332962
#   0.3349253  -1.1484169  -1.3024462   0.38086265  0.3934148  -0.6632114
#   0.7319024  -1.4473828  -0.6496567   1.1555141   1.2057103   0.33950377
#   0.1027367   1.1447593  -0.5823577  -0.92052764 -0.2765347  -0.48293784
#  -0.22830942 -0.82478446  0.46147534  0.9217476   0.7440741  -1.8674946
#  -1.2976104   1.8312244   1.237014    0.8444208   0.31961945  0.7229396
#   0.30560502  0.5612248   0.02182759  1.1239519  -0.6609922   0.4490656
#   1.7346     -1.8891575  -0.33271605 -1.816297    0.92147446  0.9853027
#  -0.7507831  -0.5805081   0.5655607   0.1363573   0.61544627 -0.7805797
#  -0.5482251   0.16675188  0.7420887  -1.2039198   0.25539887  1.1628757
#  -0.55587006  0.33774555 -1.3286929  -0.8309933   0.31563476 -0.11151444
#   0.32474992  0.6145675   1.2063448  -1.0381701   0.49675772  0.5882322
#  -0.49957946  1.4079628   0.28274885 -0.11883742 -0.01114379  1.3009143
#   1.3408889   0.81553996  0.25796223  0.46777678 -1.3489612  -0.6203611
#   1.2414404  -0.1874403   0.05353608 -0.6704947   0.9277509   0.9727417
#   1.9004235  -1.4388198  -0.508923   -0.71441025  0.31865582  0.61099595
#   0.48978448 -0.10666049  0.7105429   0.3206791  -0.00325782 -0.57139903
#  -2.020282    0.27581483 -0.20348972 -1.9408308   0.29886168 -0.18370184
#  -0.32829678  0.5940396   0.1151692   0.6441504 ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_4/gamma
# [-1.83545482e+00  1.91261601e-02  1.85620868e+00  6.68368399e-01
#   5.71176589e-01  9.37914252e-01  5.60537934e-01  3.71322408e-02
#   1.42190456e+00  2.51243281e+00  2.84845209e+00 -4.03580628e-02
#  -3.02411020e-02  2.64529198e-01  1.77023435e+00  1.00663507e+00
#   1.98970389e+00  8.52002144e-01  1.60566795e+00  1.72790647e+00
#   2.04851292e-02  6.20868355e-02  9.15721774e-01  4.49872553e-01
#   7.58669555e-01  1.94792688e+00  1.80472136e+00  6.98710382e-01
#   9.97232571e-02  9.23957944e-01  2.93479252e+00  4.55342000e-03
#   8.61282885e-01  4.42497045e-01  1.48137116e+00  3.35974693e-01
#  -9.04201046e-02  9.12112117e-01  3.67856085e-01  1.49391067e+00
#   1.36033440e+00  2.23335195e+00  5.26995242e-01  1.20936799e+00
#  -1.92450907e-03  4.25983220e-01  4.69109207e-01  3.83810967e-01
#   5.43694675e-01  6.73955023e-01 -1.91732302e-01  1.50419033e+00
#   9.94534254e-01  9.62418973e-01 -4.07593548e-02  1.50221658e+00
#   1.19877470e+00  9.72752869e-01  7.64791608e-01  1.21477079e+00
#   1.05426562e+00  6.52089119e-01  7.36810684e-01  1.29756129e+00
#  -5.52341379e-02  7.10655630e-01  8.02578390e-01  5.39070725e-01
#   1.90527618e+00  6.53423369e-01  1.08744454e+00 -2.77937930e-02
#   1.19616997e+00  9.99465957e-02 -7.10609481e-02  3.45466280e+00
#   7.32578933e-01  2.33322358e+00  1.65842295e+00  5.97300887e-01
#   1.76855874e+00  2.44340730e+00  9.49378014e-01 -3.70711446e-01
#   1.19100320e+00  2.55591345e+00  8.07233095e-01  6.60551488e-01
#   2.23261642e+00  6.50572717e-01  2.74408603e+00  3.51098132e+00
#   2.27003530e-01  3.14044428e+00  1.24771762e+00  4.67859119e-01
#   7.44288743e-01  8.87080669e-01  1.76486135e-01  1.02156270e+00
#   9.43316162e-01  3.46869439e-01  7.48553276e-01  8.72347891e-01
#   1.65261459e+00 -1.01860784e-01  8.73060107e-01  1.45024598e+00
#   1.74506593e+00  5.44743359e-01 -1.91564366e-01  7.98103809e-01
#   1.00252426e+00  1.70593715e+00  1.41543281e+00  8.47880900e-01
#   3.54745626e-01  8.06337893e-01  8.70682299e-01  1.16078901e+00
#   8.64294291e-01  3.39035600e-01  1.81615543e+00  3.67432833e-01
#   8.28483343e-01  4.81541455e-01  8.11789632e-01  1.23525417e+00
#   1.13184214e+00  1.66626632e-01  1.11329305e+00  1.25755787e+00
#   7.35579610e-01 -3.61339957e-01  1.24099982e+00  1.18962443e+00
#   2.33106711e-03  2.63511992e+00  2.23190093e+00  1.16498482e+00
#   1.13107634e+00  6.49154246e-01  5.34936726e-01  1.28442574e+00
#   1.46769977e+00  5.61959203e-03  1.54731262e+00  7.30250657e-01
#   1.17156184e+00  1.04386652e+00  2.08142829e+00 -2.33301044e-01
#  -6.33858263e-01  3.19344783e+00  5.33118844e-01  1.27330410e+00
#   1.72572732e+00  1.68528497e+00  1.04190923e-01 -1.36652231e-01]
# tensor_name:  TemporalFusionTransformer/layer_normalization_5/beta
# [-1.59992158e+00 -7.78118432e-01  1.94208956e+00  1.44774127e+00
#   3.12975526e-01 -1.72385681e+00  1.28028512e+00  4.43568751e-02
#  -7.88832247e-01 -9.83524919e-02  1.08336675e+00  1.69074965e+00
#  -4.78207499e-01  1.06348813e+00  1.88014770e+00 -3.87262642e-01
#   7.93085575e-01 -1.34036815e+00 -6.39415741e-01 -5.80594063e-01
#   1.55220616e+00 -3.68184268e-01  1.32705116e+00  6.84315264e-01
#  -1.23264916e-01 -2.81606644e-01  6.02660000e-01 -1.51430106e+00
#   1.53573608e+00  7.53762424e-01  1.61224198e+00  1.00310481e+00
#   6.92410529e-01  1.06348708e-01  8.59165490e-01  2.11741388e-01
#   1.58885920e+00 -1.06040072e+00  9.01431262e-01 -8.73503760e-02
#   9.70560968e-01 -1.53418750e-01  1.53352439e+00 -1.98621964e+00
#   1.34896469e+00 -3.33624214e-01  7.15903044e-01  6.93148434e-01
#  -1.28999960e+00 -1.02686711e-01 -2.29913354e-01  2.46416950e+00
#   3.26948106e-01 -2.55912542e+00  1.55790240e-01 -1.21698260e+00
#  -1.71393585e+00  2.60842228e+00  1.61954653e+00 -3.43542218e-01
#   2.97853023e-01 -5.59296727e-01 -1.29709587e-01  2.78898263e+00
#   3.54488105e-01 -1.22741890e+00 -1.46318400e+00 -3.77697885e-01
#   1.17652023e+00 -3.96928847e-01  1.34676814e+00  7.18997061e-01
#  -6.54875278e-01 -2.26321959e+00 -1.11130083e+00 -1.36588454e+00
#   3.84434372e-01 -4.56546187e-01  2.72144628e+00 -1.15807772e+00
#   4.51486791e-03  1.18310772e-01  2.37020217e-02 -1.40413225e+00
#  -5.20003915e-01 -2.77054995e-01  1.58394873e+00 -9.01107490e-01
#   1.50761819e+00  2.06991100e+00 -3.02456439e-01  2.51033378e+00
#   4.30244282e-02 -6.97063386e-01 -1.46253538e+00  2.27041841e+00
#  -8.93065035e-02  2.06468630e+00  1.48068562e-01 -8.26531947e-01
#   1.58489406e+00  2.04648584e-01 -1.72113669e+00 -2.11372659e-01
#  -9.13669765e-01  5.15260363e+00 -3.69353563e-01  9.31893349e-01
#   9.18120623e-01  1.95835912e+00 -1.12929130e+00 -1.01246011e+00
#  -3.75820607e-01 -1.87782574e+00  7.96564639e-01 -1.94452202e+00
#  -2.15946570e-01  4.06155109e-01  5.41339993e-01  1.46794724e+00
#  -2.34595919e+00 -3.51033397e-02 -1.53716838e+00  1.12500083e+00
#   4.35807854e-01 -6.30517751e-02 -1.29567492e+00  3.35218310e-01
#   1.00673425e+00  5.12371123e-01 -8.19766641e-01  2.32925749e+00
#  -1.23386204e+00 -1.34715998e+00 -5.06265104e-01 -1.29568827e+00
#   5.57664692e-01 -2.00400308e-01  2.88008213e-01 -5.29871345e-01
#  -6.92735314e-01 -1.60901323e-01  3.77300709e-01  1.57364404e+00
#   1.15069270e+00 -1.11517382e+00 -1.43131018e-01 -1.54685602e-01
#   2.12582797e-01  7.01930821e-01 -8.94244969e-01  1.14000356e+00
#   2.93442868e-02 -2.04662398e-01 -1.31144679e+00  1.24981189e+00
#   6.46779060e-01 -4.21574861e-01 -1.69617128e+00 -1.19507349e+00]
# tensor_name:  TemporalFusionTransformer/layer_normalization_5/gamma
# [-2.10888171e+00  1.18980718e+00 -1.00625896e+00  8.09167445e-01
#   4.34790701e-01  2.32580757e+00  4.66966361e-01  1.43424428e+00
#   9.67376530e-01  9.30752635e-01  1.65589607e+00  5.98549724e-01
#   8.36040139e-01  1.22678292e+00 -2.34723419e-01  9.59790647e-01
#  -4.00404120e-03 -6.66929841e-01  3.05325079e+00  1.94051194e+00
#   1.47381258e+00  1.11680853e+00  3.32009643e-02 -5.47365963e-01
#   2.95201480e-01  4.61166978e-01  1.44846940e+00  1.89889908e+00
#   4.95573431e-01  3.65218163e-01  9.00253713e-01  8.84962618e-01
#   1.52948713e+00  3.31106126e-01  1.85948658e+00  6.95754468e-01
#   8.88149500e-01  1.12485385e+00  1.30970752e+00  1.18336523e+00
#   1.64371872e+00  1.57574797e+00  1.60612571e+00  2.06803179e+00
#  -8.37910250e-02  1.34591365e+00  1.31148607e-01  2.49984726e-01
#   2.36336923e+00  8.76230776e-01  1.93872678e+00  6.19351983e-01
#   1.93528640e+00  5.50121546e-01  5.43022513e-01  4.23531592e-01
#  -8.44042674e-02 -1.15178013e+00  5.30988991e-01  9.30580556e-01
#   9.70690250e-01  5.69220781e-01  1.75217164e+00 -1.04650654e-01
#   1.42732131e+00  1.33544460e-01  2.33989358e+00  1.28078413e+00
#   1.74233150e+00  1.65334821e+00  5.17794073e-01 -1.10135883e-01
#   2.26638985e+00  2.43228412e+00  1.67214537e+00  2.53277898e+00
#   4.43998784e-01 -6.20252252e-01 -1.74423456e+00  1.85868502e+00
#   1.45292524e-02  1.03774989e+00  1.12860334e+00  1.49198735e+00
#   6.16611779e-01  8.16818655e-01  3.46721005e+00  1.54069364e+00
#  -1.00099714e-03  1.63189065e+00  1.40520978e+00  1.38207531e+00
#   9.71851408e-01  3.50179851e-01  9.74851727e-01  2.69062734e+00
#   1.21638095e+00  1.20716918e+00 -6.05000973e-01  1.72779584e+00
#   1.28166914e+00  1.55171204e+00  6.46365881e-01  1.15024638e+00
#   2.34924221e+00 -4.11626673e+00  9.63637650e-01  9.13551986e-01
#   2.56500220e+00  1.02474880e+00  1.47679317e+00  9.69297409e-01
#   1.23382080e+00  1.72292364e+00  2.96725798e+00  2.12812471e+00
#   7.01821685e-01 -2.47226104e-01  1.57831752e+00  2.03001809e+00
#   1.97406542e+00  1.39181614e+00  3.52171087e+00  1.18676364e+00
#   1.35223341e+00  1.52401388e+00  2.95519114e+00  2.34617257e+00
#   2.66372538e+00  8.81976783e-01  8.57571363e-01 -9.61395621e-01
#   1.24240994e+00  1.12697387e+00  2.66675401e+00  2.12173533e+00
#   1.00789177e+00  1.29331851e+00  1.38250911e+00  9.60344076e-01
#   1.32078350e+00  5.73888540e-01  8.09668005e-01  5.50131872e-02
#   9.41507995e-01  1.18240559e+00  1.04432273e+00  1.24064878e-01
#   5.64917922e-01  2.55185604e+00  4.69257236e-01  1.74051559e+00
#   1.58167708e+00  6.46921039e-01  1.33743382e+00  6.23645365e-01
#   5.21513343e-01  1.63676655e+00  1.52733696e+00  1.51189476e-01]
# tensor_name:  TemporalFusionTransformer/layer_normalization_6/beta
# [ 1.0287548  -1.0229167  -0.25986734 -1.007713   -0.59840924 -1.1300801
#   0.7703122 ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_6/gamma
# [0.2083472  0.8090068  0.38293543 0.5444393  1.4492096  0.41371375
#  1.0525787 ]
# tensor_name:  TemporalFusionTransformer/layer_normalization_7/beta
# [-1.14951283e-01 -1.66965798e-01  1.91158012e-01  3.86015862e-01
#   2.54180849e-01  5.64483330e-02  5.29160917e-01 -6.49839044e-01
#  -3.90024543e-01 -5.76260388e-01  2.18911737e-01  9.19969007e-03
#  -2.28112936e-01 -2.14233756e-01  2.18999282e-01  3.78719449e-01
#  -9.43065643e-01  5.24843991e-01  5.63250840e-01  6.41321689e-02
#   1.50665238e-01  1.29938528e-01  7.03773871e-02  2.70148218e-01
#  -7.04795480e-01 -1.41163254e-02 -7.77716711e-02 -9.07828510e-02
#  -1.87207326e-01  1.93535790e-01  3.16296064e-04 -4.58373986e-02
#   9.31241587e-02  1.88487977e-01  1.25545728e+00 -9.44018085e-03
#  -3.51317763e-01  3.10983866e-01  2.05674563e-02  2.56549865e-02
#  -1.76342413e-01 -7.68499449e-02 -4.10649985e-01 -3.52843344e-01
#   4.47286367e-01 -1.61485508e-01  3.64849865e-01 -5.28408825e-01
#  -3.15707892e-01 -7.50544593e-02  3.93297732e-01 -1.27753794e-01
#   7.70369694e-02  3.88444394e-01  3.50273103e-01 -2.37557009e-01
#  -3.45717013e-01  4.88112837e-01  8.37266296e-02  2.03835532e-01
#   4.34672125e-02  2.47713048e-02 -1.28070503e-01  1.41877547e-01
#   4.36720699e-01 -1.91406578e-01  5.55572100e-02  1.15086950e-01
#  -1.29526556e-02  5.90607047e-01 -6.79843903e-01  1.35550559e-01
#  -7.92600036e-01  5.60423195e-01 -1.29347622e-01 -6.46122873e-01
#  -3.84546548e-01 -9.76544693e-02  3.37868072e-02  3.24422657e-01
#   3.38230163e-01 -2.58712500e-01 -1.36440322e-02 -7.05013201e-02
#  -2.52572089e-01  5.19149244e-01 -4.90079105e-01 -1.17917337e-01
#   6.95961118e-01 -3.79813850e-01  6.60513341e-01 -3.15565884e-01
#   2.57211775e-01 -5.76559782e-01  2.01647222e-01  5.42773008e-01
#  -2.63853133e-01  6.14956796e-01 -1.64118230e-01 -1.78646773e-01
#  -9.30205286e-01 -5.48916943e-02  1.20540783e-01 -5.24017327e-02
#  -1.50508806e-01  5.28219461e-01  1.20665267e-01 -3.02265912e-01
#   5.31944871e-01  1.37467403e-03 -5.16169727e-01 -4.96040797e-04
#   1.82413593e-01  9.67682805e-03 -2.45702595e-01  9.61703248e-04
#  -5.33878982e-01 -6.21964395e-01  4.08438742e-01  3.69243503e-01
#   4.09967033e-03  1.08088352e-01 -4.64834690e-01 -4.57459986e-01
#   3.47167879e-01 -2.50740856e-01 -2.60620594e-01  4.86209035e-01
#  -9.57971036e-01 -1.46761701e-01 -3.70597452e-01 -1.21110715e-01
#   1.20599449e-01 -1.10963415e-02 -6.81123734e-02 -1.88978836e-01
#   1.12117100e+00  3.30973893e-01  4.33155772e-04 -6.14697114e-02
#  -1.03819378e-01 -9.20023978e-01 -5.42045891e-01  1.20170966e-01
#   4.84888077e-01 -1.34322420e-02  1.16576023e-01 -6.78864598e-01
#  -3.82926971e-01  7.00581372e-01 -1.09763563e-01 -2.20371127e-01
#  -3.09266776e-01 -2.66101241e-01 -9.52241182e-01  5.53247094e-01
#   3.08170944e-01 -5.98062426e-02  1.17344648e-01  3.01540464e-01]
# tensor_name:  TemporalFusionTransformer/layer_normalization_7/gamma
# [-5.54180384e-01  7.71814510e-02  2.73388535e-01 -1.90679893e-01
#  -1.75206475e-02  2.04047590e-01  1.84046984e-01  3.64416033e-01
#   1.04883695e+00  1.12416975e-01  3.10587317e-01  4.12568539e-01
#   1.56288850e+00  8.79633904e-01  1.13015413e+00  1.10109173e-01
#  -6.19320832e-02  5.97897582e-02  3.00595704e-02  4.58055958e-02
#  -4.45595652e-01 -4.86609071e-01  5.20328060e-02 -1.11610822e-01
#   5.75789273e-01  9.61067621e-03  3.39669824e-01 -2.34426819e-02
#   7.98959658e-02 -7.05728121e-03  3.99225682e-01  5.63146234e-01
#   1.38171995e+00  8.70579720e-01  1.01997948e+00  9.55217555e-02
#   3.02578837e-01  1.37474567e-01 -2.07339171e-02  1.71803117e+00
#   1.13630307e+00 -2.24989769e-03  5.40650338e-02  4.71573412e-01
#   1.37137198e+00  1.61348701e+00  1.99091345e-01  3.34476456e-02
#  -1.70894459e-01  1.73528922e+00 -2.08267085e-02  9.22420323e-01
#   9.18659627e-01  3.96175981e-01  4.78886753e-01  7.25526929e-01
#   8.27311456e-01  2.01048589e+00  2.58871287e-01 -8.82047340e-02
#   1.47963762e+00  5.61622500e-01  9.49828744e-01 -2.03673467e-01
#   1.67726350e+00  1.32455969e+00  1.00531685e+00  4.28726554e-01
#   8.99426103e-01  9.71015915e-02  1.43197596e+00  1.16348170e-01
#   1.78358361e-01  6.96650684e-01  9.31878924e-01  8.31167161e-01
#  -1.12046733e-01  3.79927009e-01  1.45134795e+00  5.81960440e-01
#  -6.87297881e-01  5.62722921e-01  4.92340505e-01  1.76248834e-01
#   2.37534904e+00  1.52904049e-01  1.36016345e+00 -3.31210315e-01
#  -9.70745087e-02  2.09466562e-01  1.51673877e+00  5.63735902e-01
#   6.29854202e-01 -2.22483635e-01  1.19813609e+00  6.34374440e-01
#   8.58094633e-01  9.21904385e-01  2.79842526e-01 -1.60806198e-02
#   8.26857612e-02  2.03147721e+00  7.44846642e-01  3.72177869e-01
#   1.08420324e+00  7.57383406e-01  1.28228724e-01  5.87457381e-02
#   2.80744374e-01  2.37410396e-01  1.88201511e+00  6.20637983e-02
#   1.14285767e+00  4.43303846e-02 -2.23759890e-01  7.79128134e-01
#   1.64817452e+00  1.35471976e+00  1.24310946e+00  8.87935981e-02
#   1.07653558e+00 -7.24133998e-02  2.07634807e+00  1.35259718e-01
#   1.62575752e-01  1.98331177e-01  5.76565087e-01 -1.24239832e-01
#  -2.85574973e-01  1.99383688e+00 -6.01622947e-02  1.10649455e+00
#   1.75508714e+00  2.73551762e-01  1.00427437e+00  4.05503362e-01
#   2.19156742e+00  2.91591823e-01  6.60818070e-02  9.07415092e-01
#   1.00010955e+00  3.99394065e-01  5.24396002e-01  2.63625950e-01
#   1.10544629e-01 -9.26107052e-04  1.43597662e+00 -1.59965549e-03
#   6.53726421e-03  5.81808686e-01  2.96611618e-02 -7.65604079e-02
#   9.76025462e-02 -5.44023514e-01  7.53573895e-01  2.06124619e-01
#   1.00826710e-01  8.85107696e-01  1.69302380e+00  2.35309625e+00]
# tensor_name:  TemporalFusionTransformer/layer_normalization_8/beta
# [-8.18500072e-02  7.01056182e-01  3.80740881e-01  1.22021437e-01
#   5.64078689e-01  2.98421290e-02  6.93318844e-01 -1.46407172e-01
# ...
#  -1.57986674e-02  3.85912061e-02 -4.66153063e-02 -2.26185210e-02
#  -1.82779932e+00  2.32560746e-02  4.04580645e-02  2.99398974e-02
#  -1.93025637e-02  1.44350365e-01  2.79743820e-01  6.20403625e-02
#   2.15530619e-02  1.09184794e-02  2.77583208e-02 -3.45533080e-02
#  -2.80317646e-02  8.28559976e-03  3.51563394e-02 -2.82794982e-02
#  -2.16794312e-02 -4.14890274e-02  7.36956671e-02 -2.07506157e-02
#   6.65312633e-02  1.87537912e-02 -2.66154259e-02 -5.01498766e-02
#  -4.30721007e-02 -4.44913357e-02  2.23663170e-02  6.24721050e-02
#  -4.00404520e-02  1.22662848e-02 -1.89950466e-02 -3.13889720e-02
#   3.59227210e-02  1.91646647e-02 -2.39148512e-02 -5.35042621e-02
#   4.77071255e-02 -1.75221354e-01 -7.24074990e-02  5.01425266e-02
#  -2.13704277e-02  9.22192447e-03  3.77597141e+00 -2.72952449e-02
#   4.50234069e-03 -1.12239167e-01  3.82699282e-03 -1.15885260e-02
#   3.11030932e-02 -2.99511384e-03  6.13901131e-02 -2.29739785e+00]
# tensor_name:  TemporalFusionTransformer/time_distributed_76/kernel
# [[ 0.0692906   0.00070604 -0.11146559 ... -0.08707989  0.10675798
#   -0.13418521]
#  [ 0.07213791 -0.11921434 -0.03032602 ...  0.19059995 -0.09699543
#    0.03653907]
#  [-0.15100165 -0.00536395  0.12071673 ...  0.08555374  0.03579
#   -0.09757946]
#  ...
#  [-0.07821012 -0.10244549 -0.15755817 ...  0.12323008  0.10411251
#    0.0269123 ]
#  [-0.16626032 -0.01685705  0.14957263 ...  0.18294312 -0.09481072
#   -0.04716079]
#  [ 0.12659653  0.10596232 -0.0714258  ... -0.04842198 -0.00283754
#   -0.18190378]]
# tensor_name:  TemporalFusionTransformer/time_distributed_77/bias
# [-0.03657715 -0.06761964 -0.05421768 -0.03529188 -0.04446213 -0.01081561
#  -0.04432873 -0.05845478 -0.10251709 -0.05387476  0.06263655 -0.00920459
#  -0.08073474 -0.01891791 -0.03562883  0.09029873  0.08103687 -0.0451116
#  -0.06029096 -0.01524525 -0.03027222  0.0095572   0.1105655   0.00647752
#   0.25991747 -0.11616829 -0.08358703 -0.05000608 -0.05670204 -0.09056506
#   0.02189314 -0.05042298 -0.02509212 -0.10388183 -0.10058738 -0.02253507
#  -0.06792781 -0.0427559  -0.0985169  -0.02001786 -0.02718002 -0.03135652
#   0.12721811  0.15218236  0.0068888  -0.10270683  0.01154943 -0.02756623
#  -0.11403006  0.03040769 -0.09546372  0.11798777 -0.11084082 -0.00046073
#  -0.08289201 -0.07087152 -0.0376799  -0.0469145   0.01043009 -0.00913589
#   0.00744757 -0.07229251 -0.00354919 -0.11731336 -0.0867901  -0.09518203
#  -0.11922545 -0.04507833  0.15138973  0.00348499 -0.06578606 -0.00541542
#  -0.13740993  0.0298212   0.03977186 -0.12709658 -0.02178136 -0.07189638
#  -0.1603064   0.03771512  0.1017453  -0.03864057 -0.0964316   0.02900326
#  -0.05983236 -0.06721581 -0.03505091  0.13774839 -0.03683995 -0.04602332
#  -0.06172874 -0.03165624 -0.04540794  0.08732902 -0.07491018 -0.12853928
#   0.02527671 -0.02676747 -0.08245569 -0.03953749 -0.04521307 -0.0861734
#   0.06483386 -0.04463002 -0.03803578 -0.01399596 -0.11656175 -0.05805534
#   0.04345163 -0.09759822  0.0043669  -0.08392099 -0.01061813 -0.005605
#  -0.01102902 -0.09962437 -0.03090697 -0.00806888 -0.03631851 -0.01108412
#  -0.02732574 -0.03513097 -0.03336038 -0.03876983 -0.0383325  -0.12655245
#  -0.04206924 -0.01269214  0.00229755 -0.04767963 -0.00192821 -0.11286237
#  -0.09913412  0.03608513 -0.03843503 -0.07563806  0.01315845 -0.0252135
#  -0.01384037 -0.08473631  0.06407528  0.03661977 -0.09087955 -0.06147425
#  -0.11837509 -0.02712372  0.08024855 -0.00861642 -0.0986428   0.00587458
#   0.16211542 -0.08689344 -0.01743649  0.05643182 -0.03773026 -0.0565325
#  -0.09191889 -0.00399573 -0.05180174  0.08837942]
# tensor_name:  TemporalFusionTransformer/time_distributed_77/kernel
# [[ 0.17091219 -0.00538121 -0.00696635 ...  0.11398061  0.15760608
#   -0.1640707 ]
#  [ 0.00813344 -0.11192437  0.09104685 ... -0.00909526  0.00965681
#    0.08475368]
#  [ 0.14461736  0.10825532  0.31947157 ...  0.08219798  0.13079914
#   -0.113005  ]
#  ...
#  [ 0.1534691  -0.1141627  -0.02054522 ... -0.07939806 -0.0630051
#    0.1288419 ]
#  [-0.13399008  0.15487318  0.1851935  ...  0.06799995 -0.13784988
#   -0.09570135]
#  [-0.02662884 -0.03935841 -0.12424906 ...  0.03461178 -0.1072382
#    0.02132453]]
# tensor_name:  TemporalFusionTransformer/time_distributed_78/bias
# [-0.78330976 -0.02706927  0.9253397 ]
# tensor_name:  TemporalFusionTransformer/time_distributed_78/kernel
# [[ 3.48037807e-03 -1.55846868e-03  1.25897527e-02]
#  [ 4.53935415e-02  2.49346923e-02 -1.70358941e-02]
#  [-5.70312841e-03 -1.01703629e-02  2.01032422e-02]
#  [ 4.85981815e-03 -2.62943050e-03  7.79461488e-03]
#  [-5.73864346e-03  1.04261853e-03 -9.18330345e-03]
#  [-2.87910290e-02 -2.97888424e-02  5.02375439e-02]
#  [ 3.20874620e-03  3.66429007e-03  3.53575032e-03]
#  [ 1.90854468e-03  1.13201328e-03 -1.67545245e-03]
#  [ 1.38332658e-02 -2.41649360e-03  3.51120606e-02]
#  [-3.66556048e-01 -1.63753018e-01  2.56790906e-01]
#  [-1.09620607e-02 -1.39035787e-02  2.44478378e-02]
#  [-6.10700203e-03 -8.03784933e-03  1.59072783e-02]
#  [ 4.44641933e-02  4.27791961e-02 -3.69545147e-02]
#  [ 4.15354073e-02  4.58864262e-04  1.72946509e-02]
#  [ 2.79105119e-02  3.19874622e-02 -4.85882126e-02]
#  [-1.33934198e-03 -1.20469823e-03  7.39059236e-04]
#  [ 6.59192633e-03  1.14866635e-02  4.61737020e-03]
#  [-7.82569405e-03 -2.97067920e-03  6.98913122e-03]
#  [ 3.68274972e-02  3.14391628e-02  3.93863730e-02]
#  [-1.76176261e-02 -1.58390105e-02  1.23301707e-02]
#  [-4.81045432e-02 -4.45504524e-02  5.50815612e-02]
#  [-6.72134222e-04  6.22597174e-04  9.97188129e-03]
#  [-9.74714570e-03  9.64337401e-03 -1.99482217e-02]
#  [ 3.43814977e-02  2.56271865e-02 -2.56163459e-02]
#  [ 6.54014479e-03 -1.42487660e-02  1.00561213e-02]
#  [-5.14134648e-04 -5.97673608e-03  1.83403753e-02]
#  [ 3.93345691e-02  1.97683480e-02  6.17458532e-03]
#  [ 4.12291139e-02  3.53436582e-02 -2.94816568e-02]
#  [ 3.93972173e-03  5.55418059e-03  8.48497823e-03]
#  [-5.19459210e-02 -3.66400070e-02  2.37347577e-02]
#  [-5.24662109e-03 -5.59786987e-03  1.52166393e-02]
#  [-4.35797311e-02 -6.58317208e-02 -1.65287450e-01]
#  [-7.02029979e-03 -7.25721568e-03  9.52611864e-03]
#  [ 7.93036073e-03  5.48168877e-03 -3.13511025e-03]
#  [-1.80995408e-02 -2.07909569e-02  2.78906487e-02]
#  [ 7.45862443e-03  5.94913785e-04  8.54162220e-03]
#  [ 2.53825504e-02  3.13352086e-02 -3.19669433e-02]
#  [ 3.08515448e-02  5.11630885e-02  1.73470154e-01]
#  [ 1.14573147e-02  1.42398421e-02 -1.36220492e-02]
#  [ 2.88335280e-03 -2.13177921e-03 -9.10406858e-02]
#  [-1.80836916e-01  3.00326735e-01  7.55659401e-01]
#  [ 8.60196538e-03  2.42625223e-03  5.64640295e-03]
#  [-1.78693589e-02 -4.36317455e-03 -6.06384128e-03]
#  [-9.65808332e-03  2.62007955e-02  1.00800218e-02]
#  [-1.00144437e-02 -1.32826418e-02  2.06302535e-02]
#  [ 8.14397819e-03  5.37999487e-03 -2.41677929e-03]
#  [ 2.45804768e-02  1.88696049e-02 -2.42359545e-02]
#  [-1.86113771e-02 -2.05744784e-02  2.73961667e-02]
#  [-1.54964887e-02 -1.69012193e-02  2.75995489e-02]
#  [ 2.60945279e-02  2.76025459e-02 -3.11148986e-02]
#  [ 5.84463552e-02  2.66307648e-02  1.31809805e-03]
#  [-3.77594121e-03 -1.69414505e-02  2.58692037e-02]
#  [-3.89412511e-03  3.81612685e-03 -5.63005172e-03]
#  [ 1.20550524e-02  1.21419597e-03  4.99534048e-03]
#  [-9.09978896e-03  4.07029362e-03 -5.41418791e-02]
#  [ 5.91180101e-02  4.98106033e-02 -2.92586926e-02]
#  [ 3.55954356e-02  4.57244180e-02 -1.32340230e-02]
#  [ 3.43975471e-03  2.25313148e-03 -1.49026839e-03]
#  [ 2.52092350e-02  2.46914458e-02 -1.88011341e-02]
#  [ 6.54286612e-03  4.81343735e-03  6.07499015e-03]
#  [ 1.79581866e-01  3.71352397e-02 -5.63372392e-04]
#  [ 7.96099976e-02  2.23016217e-02 -9.27514676e-03]
#  [-5.94991166e-03 -1.03439195e-02  2.17359737e-02]
#  [-2.46962905e-01  2.24502496e-02  3.92509550e-01]
#  [-1.92583930e-02 -1.05986344e-02  4.17677127e-03]
#  [-5.21703996e-03 -4.26972099e-03  4.15119343e-03]
#  [ 9.33091901e-03  1.63701139e-02 -2.63041221e-02]
#  [ 4.75314856e-02  5.46393432e-02 -2.18180381e-02]
#  [-7.69620901e-03  6.05373271e-03 -9.59339365e-03]
#  [ 2.06644554e-03 -3.49594420e-03  6.54695369e-03]
#  [ 7.06080437e-01  6.64637566e-01  4.47792321e-01]
#  [ 1.27564976e-02  2.22195070e-02 -3.12237255e-02]
#  [ 1.67795978e-02  1.98563728e-02 -2.29075775e-02]
#  [-3.05042090e-03 -5.61878271e-03  2.89269583e-03]
#  [-6.70542009e-03 -1.55068599e-02  3.06038558e-02]
#  [-9.68089849e-02 -2.84838468e-01 -2.84689128e-01]
#  [ 6.61896076e-03  5.99398371e-03 -6.55185431e-03]
#  [ 3.75375971e-02  4.04113084e-02  5.13015781e-04]
#  [-1.75857153e-02 -2.59284116e-02  4.24639508e-02]
#  [-3.05939186e-02 -3.17287967e-02  4.88067679e-02]
#  [-2.23297607e-02  6.27261540e-03 -3.67778055e-02]
#  [-5.05689606e-02 -6.92690955e-03  3.90049331e-02]
#  [-1.71314515e-02 -2.33319104e-02  3.63040008e-02]
#  [ 1.11026252e-02 -2.30879784e-02  3.83972824e-02]
#  [ 2.13124137e-02  9.07850731e-03  9.37232189e-03]
#  [ 4.41926019e-03  6.33881334e-03 -6.76692231e-03]
#  [ 2.25129463e-02  2.63663158e-02 -4.82545421e-02]
#  [-2.13775057e-02  2.89691705e-03 -3.22788619e-02]
#  [-6.73957285e-04  5.41115552e-03 -1.42632658e-02]
#  [-4.66345670e-03 -1.75690074e-02  2.19981093e-02]
#  [ 1.18502369e-03 -9.87766776e-04  3.75718530e-03]
#  [-4.33562011e-01 -3.30468416e-01 -3.92379522e-01]
#  [-1.03623979e-03  1.57413841e-03 -4.94657829e-03]
#  [ 2.70727538e-02  1.46572050e-02  4.52711154e-03]
#  [ 2.43284245e-04 -5.58641295e-06  1.55178620e-03]
#  [ 5.19241393e-03  5.49494987e-03 -6.12379424e-03]
#  [ 3.77238425e-03  5.42809721e-03 -1.00351553e-02]
#  [ 2.54172742e-01  1.60221517e-01 -1.45919379e-02]
#  [-6.47228851e-04 -4.16987576e-03  9.41137597e-03]
#  [-1.88712105e-02 -2.47108713e-02  1.47792045e-02]
#  [-6.20987296e-01 -5.95814705e-01 -6.48178816e-01]
#  [ 1.39740380e-02  1.89191289e-02 -3.67690325e-02]
#  [-5.19141462e-03  2.14938400e-03 -1.97310392e-02]
#  [ 2.56067347e-02 -1.07522169e-03  3.05912439e-02]
#  [ 3.53080556e-02  3.89678590e-02 -5.04778065e-02]
#  [-9.69739854e-02 -1.31098285e-01 -2.69116182e-02]
#  [ 1.17551116e-02  7.32781657e-04  8.17605630e-02]
#  [-1.12271653e-02 -4.30688495e-04 -7.12869018e-02]
#  [-1.02773476e-02  1.53633161e-03 -3.86469476e-02]
#  [ 4.02984060e-02  4.11455426e-03  1.57171994e-01]
#  [-1.00535760e-02 -1.19594475e-02  4.47589643e-02]
#  [ 3.30836661e-02  5.41418828e-02  1.54665872e-01]
#  [-3.67412083e-02 -1.67275369e-02  1.18734948e-02]
#  [-3.04628629e-03 -1.78257411e-03  7.31327059e-03]
#  [-4.36209440e-02 -7.67004583e-03 -2.45667696e-02]
#  [-1.34463683e-02 -4.02256176e-02 -1.42679021e-01]
#  [-2.54036742e-03 -3.19908257e-03  2.57734628e-03]
#  [-4.04966529e-03  3.91977048e-03 -3.37225012e-02]
#  [-1.98251195e-02 -2.96976455e-02  2.95182988e-02]
#  [-2.91648179e-01 -3.76908600e-01 -3.92030686e-01]
#  [ 3.67698865e-03 -3.75610543e-05  3.88991414e-03]
#  [ 2.94095650e-02  3.39327082e-02 -5.09072244e-02]
#  [ 3.12864641e-03 -8.32089502e-03  4.28784490e-02]
#  [-1.87812594e-03 -2.23426800e-03  2.07220810e-03]
#  [-1.84729288e-03  6.57845376e-05 -2.12546345e-03]
#  [ 1.74138956e-02  2.23494619e-02 -3.90326381e-02]
#  [-1.26739945e-02 -1.93846654e-02  3.27166840e-02]
#  [ 5.09484261e-02  2.98291743e-02 -3.23029794e-02]
#  [-3.83158866e-03  3.68630863e-03 -1.63659062e-02]
#  [ 1.54491570e-02  1.80342663e-02 -3.40273008e-02]
#  [ 5.56010716e-02  5.20263128e-02 -3.95907052e-02]
#  [-3.73267196e-02 -3.69637758e-02  3.33294086e-02]
#  [ 4.96102404e-03  1.01801306e-02 -1.65343620e-02]
#  [-2.58942768e-02  4.27003652e-02 -1.34085461e-01]
#  [-3.80079709e-02 -5.16219884e-02  4.88953143e-02]
#  [ 2.94571575e-02  7.72489421e-03  1.86003521e-02]
#  [-6.11670897e-04  1.76996837e-04 -3.00801219e-03]
#  [-1.18088555e-02 -6.22063130e-03 -1.48298661e-03]
#  [-1.46043114e-02 -1.95295848e-02  3.01634409e-02]
#  [ 6.96088362e-04  6.88011176e-04 -1.18898530e-03]
#  [-4.21395041e-02 -3.26887518e-02  3.50452401e-02]
#  [-2.01383188e-01 -1.30468145e-01 -2.16774851e-01]
#  [ 5.31013682e-02  5.35963960e-02 -4.05673049e-02]
#  [ 2.74257779e-01  1.86245158e-01  2.09159493e-01]
#  [-2.63827443e-02 -3.14288810e-02  4.25167717e-02]
#  [ 1.82548732e-01  2.03064606e-02 -1.13355801e-01]
#  [ 2.21850760e-02  2.85611916e-02 -4.43713367e-02]
#  [ 5.77313360e-04 -1.87934947e-03 -1.01901230e-03]
#  [ 4.56549190e-02  2.43007373e-02  4.45697224e-05]
#  [-2.10172553e-02 -2.70249285e-02  3.85399573e-02]
#  [ 1.08372550e-02  3.17908078e-02 -1.74180716e-02]
#  [ 3.28745171e-02  2.67389975e-02 -2.35371348e-02]
#  [ 3.80196702e-03  6.02554902e-03 -1.89311318e-02]
#  [-6.63346052e-03  1.06211193e-02 -2.22883038e-02]
#  [ 1.40406741e-02 -4.21199016e-03  2.48290766e-02]
#  [-1.73133723e-02 -3.11702304e-02  4.46189977e-02]
#  [-1.58866644e-02 -1.72635894e-02  1.97884161e-02]
#  [ 1.27803218e-02  6.05005655e-04  1.43296029e-02]
#  [-2.12179031e-03 -7.34051783e-03  2.01303419e-02]
#  [ 1.50741357e-03 -2.12461967e-03 -1.38638830e-02]]
# tensor_name:  TemporalFusionTransformer/time_distributed_8/bias
# [-0.09843459  0.06162867  0.0905738  -0.02972479  0.05441907 -0.00703469
#  -0.0444316 ]
# tensor_name:  TemporalFusionTransformer/time_distributed_8/kernel
# [[-0.20327273  0.2695471   1.0155278  ... -0.61185795 -0.6248087
#    0.2927567 ]
#  [ 0.14568962 -0.1888469  -0.7912398  ... -0.61486727  0.13612461
#    0.9622771 ]
#  [-0.30675048  0.2244282   0.5953603  ... -0.9352715  -0.16708869
#   -0.28279677]
#  ...
#  [-0.48571146 -0.74963516  0.78841156 ...  0.00287019 -0.6031951
#   -0.7480628 ]
#  [ 0.9028742  -0.51873076  0.5370659  ...  0.528658    1.0481306
#    0.01652563]
#  [ 0.39631397  0.62209356  0.6677646  ...  1.1930134   0.3464191
#    0.09742567]]
# tensor_name:  TemporalFusionTransformer/time_distributed_9/bias
# [ 0.0429352   0.15112717  0.39500788  0.33971766  0.32764214  0.16286393
#   0.40513644  0.09754312  0.2215621   0.17541276  0.29569596  0.39145577
#   0.26483816  0.22050957  0.2682563   0.20159791  0.18315478  0.2748105
#   0.2645539   0.27480274  0.22594813  0.17394309  0.23057605 -0.01757061
#   0.19359243  0.13824621  0.0633139   0.15373607  0.21877952  0.10699753
#   0.17620464  0.3896565   0.36542037  0.287966    0.27910966  0.14401476
#   0.25770697  0.46059057  0.32738945  0.19411452  0.2112202   0.20799196
#   0.12636688  0.04032052  0.15561771  0.22506706  0.48428634  0.11405218
#   0.3043387   0.1719545   0.28884542  0.1281909   0.07625174  0.49342456
#   0.04465048  0.2829707   0.10849817  0.16673705  0.01046502 -0.41227916
#   0.16803978  0.24527988 -0.24754244  0.12456115  0.16799529  0.3153934
#   0.17923476  0.1947498   0.30501583 -0.18846512  0.29289994  0.43172398
#   0.19036771  0.19800478  0.22424571  0.08922544  0.11916415  0.36139774
#   0.30991158 -0.14958519  0.3849456   0.16754629  0.3247412   0.2407292
#   0.46307272  0.35918403  0.12845626  0.1076531   0.302359    0.1846562
#  -0.08271345  0.08586058  0.16032854  0.16558966  0.08710976  0.31771487
#   0.22075406  0.11025768  0.09790181  0.3158233   0.10872696  0.16212274
#   0.13952187  0.06407256  0.2741938  -0.0142928   0.2429892   0.13160427
#   0.3911943   0.24604416  0.18759492  0.31593707  0.20314987  0.26796275
#   0.16507399  0.4354539   0.17828907  0.20698701  0.19115557  0.30161217
#   0.16704158  0.3576122   0.20346715  0.07549496  0.21090004  0.1894887
#   0.3365991   0.15808418  0.08061932  0.09721232  0.16257676  0.12422798
#   0.04711556  0.1236388   0.35687417  0.25007147  0.19860525  0.13898782
#   0.21349004  0.10268286  0.19697408  0.27585372  0.21803918 -0.07065853
#   0.24363527  0.27072704  0.25843713  0.4394912   0.25195172  0.0150876
#   0.09719622  0.22897616  0.26331976  0.06477949  0.19789872  0.27930036
#   0.2758314   0.30194366  0.29136857  0.06450487]
# tensor_name:  TemporalFusionTransformer/time_distributed_9/kernel
# [[ 0.7237038  -1.258088   -0.8309961  ... -1.0309584  -0.79689723
#    0.9218977 ]
#  [ 0.07105687  0.52016217  0.33282575 ...  0.3720959   0.20282643
#    0.27167273]
#  [-0.701835    1.2723508   0.5520538  ...  0.5774065   0.4649765
#   -0.92533845]
#  ...
#  [ 0.61198366 -1.1519203  -0.6201723  ... -0.55849683 -0.5041852
#    0.8828831 ]
#  [ 0.74209183 -1.2607685  -0.54741526 ... -0.69815713 -0.19844638
#    1.1201717 ]
#  [-0.16377334 -0.21868093 -0.3983411  ... -0.7281431  -0.47607577
#   -0.07631542]]
# # Total number of params: 3156068
# WARNING:tensorflow:From /Gdrive/My Drive/TFT/tft/libs/utils.py:200: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# INFO:tensorflow:Restoring parameters from volatility_test/saved_models/volatility/fixed/TemporalFusionTransformer.ckpt
# Done.
# time: 26 s

# %%
print("Normalised quantile losses: P50={}, P90={}".format(p50_loss.mean(), p90_loss.mean()))
# Out:
# Normalised quantile losses: P50=0.05105934223257187, P90=0.027524457311238593
# time: 1.5 ms

# %%
for k in best_params:
  print(k, " = ", best_params[k])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-35f50446bad4> in <module>()
# ----> 1 for k in best_params:
#       2   print(k, " = ", best_params[k])
#
# NameError: name 'best_params' is not defined
# time: 17.1 ms

# %%
for k in params:
  print(k, " = ", params[k])
# Out:
# dropout_rate  =  0.3
# hidden_layer_size  =  160
# learning_rate  =  0.01
# max_gradient_norm  =  0.01
# minibatch_size  =  64
# model_folder  =  volatility_test/saved_models/volatility/fixed
# num_heads  =  1
# stack_size  =  1
# total_time_steps  =  257
# num_encoder_steps  =  252
# num_epochs  =  100
# early_stopping_patience  =  5
# multiprocessing_workers  =  5
# column_definition  =  [('Symbol', <DataTypes.CATEGORICAL: 1>, <InputTypes.ID: 4>), ('date', <DataTypes.DATE: 2>, <InputTypes.TIME: 5>), ('log_vol', <DataTypes.REAL_VALUED: 0>, <InputTypes.TARGET: 0>), ('open_to_close', <DataTypes.REAL_VALUED: 0>, <InputTypes.OBSERVED_INPUT: 1>), ('days_from_start', <DataTypes.REAL_VALUED: 0>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_week', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('day_of_month', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('week_of_year', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('month', <DataTypes.CATEGORICAL: 1>, <InputTypes.KNOWN_INPUT: 2>), ('Region', <DataTypes.CATEGORICAL: 1>, <InputTypes.STATIC_INPUT: 3>)]
# input_size  =  8
# output_size  =  1
# category_counts  =  [7, 31, 53, 12, 4]
# input_obs_loc  =  [0]
# static_input_loc  =  [7]
# known_regular_inputs  =  [2]
# known_categorical_inputs  =  [0, 1, 2, 3, 4]
# time: 2.44 ms

# %% [markdown]
# ## Interpretability Use Cases
# The relationships learnt by the TFT can also be studied using the trained model, through:
#
# 1. Analyzing the variable selection weights to identify significant features for the prediction problem.
# 2. Visualizing distributions of self-attention weights to determine the presence of any persistent temporal relationships.
#
# In the remainder of this section, we demonstrate two interpretability use cases to showcase the above.
#
# ### Generate Weights for Interpretability
# First, we generate all necessary variable selection and attention weights required for analysis.

# %%
# Store outputs in maps
counts = 0
interpretability_weights = {k: None for k in ['decoder_self_attn', 
                                              'static_flags', 'historical_flags', 'future_flags']}

tf.reset_default_graph()
with tf.Graph().as_default(), tf.Session(config=tf_config) as sess:

    tf.keras.backend.set_session(sess)
    
    # Create a new model & load weights
    model = ModelClass(params, 
                                    use_cudnn=True)
    model.load(model_folder)
    for identifier, sliced in test.groupby('id'):
        
        print("Getting attention weights for {}".format(identifier))
        weights = model.get_attention(sliced)
        
        for k in interpretability_weights:
            w = weights[k]
            
            # Average attentin across heads if necessary
            if k == 'decoder_self_attn':
                w = w.mean(axis=0)
            
                # Store a single matrix for weights to reduce memory footprint
                batch_size, _, _ = w.shape                 
                counts += batch_size
            
            if interpretability_weights[k] is None:
                interpretability_weights[k] = w.sum(axis=0)
            else:
                interpretability_weights[k] += w.sum(axis=0)

interpretability_weight = {k: interpretability_weights[k]/counts for k in interpretability_weights}

print('Done.')

# %% [markdown]
# ### Use Case 1: Analyzing Variable Importance
#
# Next, we analyze the distribution of variable selection weights on the input layer -- using this to quantify the relative importance of a given feature for the prediction problem in general. This is split into variable importance for static covariates, time-varying historical inputs variables and known future inputs as shown below.

# %%
import numpy as np
def get_range(static_gate, axis=None):
    """Returns the mean, 10th, 50th and 90th percentile of variable importance weights."""
    return {'Mean': static_gate.mean(axis=axis), 
               '10%': np.quantile(static_gate, 0.1, axis=axis),
               '50%': np.quantile(static_gate, 0.5, axis=axis),
               '90%': np.quantile(static_gate, 0.9, axis=axis)}

# %% [markdown]
# #### Static Variable Importance

# %%
def flatten(x):
    static_attn = x
    static_attn = static_attn.reshape([-1, static_attn.shape[-1]])
    return static_attn

static_attn = flatten(interpretability_weights['static_flags'])
m = get_range(static_attn, axis=0)
pd.DataFrame({k: pd.Series(m[k], index=['ID']) for k in m})

# %% [markdown]
# #### Temporal Variable Importance -- Past Inputs

# %%
x = flatten(interpretability_weights['historical_flags'])
m = get_range(x, axis=0)
pd.DataFrame({k: pd.Series(m[k], index=['Hour of Day', 'Day of Week', 'Time Index', 'Target']) for k in m})

# %% [markdown]
# #### Temporal Variable Importance -- Future Inputs

# %%
x = flatten(interpretability_weights['future_flags'])
m = get_range(x, axis=0)
pd.DataFrame({k: pd.Series(m[k], index=['Hour of Day', 'Day of Week', 'Time Index']) for k in m})

# %% [markdown]
# ### Use Case 2: Visualizing Persistent Temporal Patterns
# Lastly, we analyse the distribution of self-attention weights across various horizons to see if any persistent temporal patterns exist within the dataset. This allows us to identify any seasonal patterns or lagged relationships in the dataset, based on which past time steps are consistently important for predictions at a given horizon.
#
# We visualize this using the average attention pattern for various prediction horizons, as shown below:

# %% [markdown]
# #### Mean Attention Weights for Various Prediction Horizons

# %%
# Plotting libraries & Functions
import plotly.offline
from plotly.offline import download_plotlyjs, init_notebook_mode, plot
import plotly.graph_objs as go
import cufflinks as cf
from IPython.display import HTML

# Loads plotly charts
def iplot(fig, s='plot.html'):
    filename = os.path.join(output_folder, s)
    plotly.offline.plot(fig, filename=filename, auto_open=False)
    return HTML(filename)    

def plotly_chart(df, title=None, kind='scatter', x_label=None, y_label=None, secondary_y=None, fill=None,
                shape=None, subplots=False):
    
    fig = df.iplot(asFigure=True, title=title, kind=kind, xTitle=x_label, yTitle=y_label, secondary_y=secondary_y,
                  fill=fill, subplots=subplots, shape=shape)

    return iplot(fig)

# %%
self_attn = interpretability_weights['decoder_self_attn']

means = pd.DataFrame({"horizon={}".format(k): self_attn[model.num_encoder_steps+k-1, :] 
                      for k in [1, 5, 10, 15, 20]})
means.index -= model.num_encoder_steps

plotly_chart(means,
             x_label="Positiion Index (n)",
             y_label="Mean Attention Weight",
             title="Average Attention Pattern at Various Prediction Horizons")
