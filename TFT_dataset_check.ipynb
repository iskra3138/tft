# %% [markdown]
# <a href="https://colab.research.google.com/github/iskra3138/tft/blob/master/TFT_dataset_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preliminary

# %%
# Uses pip3 to install necessary packages 
# !pip3 install pyunpack wget patool plotly cufflinks --user 
# Resets the IPython kernel to import the installed package. 
import IPython 
app = IPython.Application.instance() 
app.kernel.do_shutdown(True)

# %%
# install to download only tft directory 
# !pip install git+git://github.com/HR/github-clone#egg=ghclone
# !ghclone https://github.com/google-research/google-research/tree/master/tft

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
cd tft
# Out:
# /content/tft

# %%
import data_formatters.base
import expt_settings.configs
import pandas as pd
import gc

# %%
ExperimentConfig = expt_settings.configs.ExperimentConfig

# %% [markdown]
# # Electricity

# %%
# where $EXPT can be any of {volatility, electricity, traffic, favorita}, 
# and $OUTPUT_FOLDER denotes the root folder in which experiment outputs are saved.
EXPT='electricity'
OUTPUT_FOLDER='electricity_test'

# %%
# download $EXPT data
# !python3 -m script_download_data $EXPT $OUTPUT_FOLDER

# %%
config = ExperimentConfig(EXPT, OUTPUT_FOLDER)
formatter = config.make_data_formatter()
data_formatter=formatter

raw_data = pd.read_csv(config.data_csv_path, index_col=0)
train, valid, test = data_formatter.split_data(raw_data)
train_samples, valid_samples = data_formatter.get_num_samples_for_calibration()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Formatting train-valid-test splits.
# Setting scalers with training data...

# %%
print (len(raw_data), len(train), len(valid), len(test))
# Out:
# 2198072 1923536 274536 123984

# %%
print (train_samples, valid_samples)
# Out:
# 450000 50000

# %%
raw_data.head()
# Out:
#        power_usage        t  ...  categorical_day_of_week categorical_hour
# 17544     2.538071  26304.0  ...                        2                0
# 17545     2.855330  26305.0  ...                        2                1
# 17546     2.855330  26306.0  ...                        2                2
# 17547     2.855330  26307.0  ...                        2                3
# 17548     2.538071  26308.0  ...                        2                4
#
# [5 rows x 13 columns]

# %% [markdown]
# # Traffic

# %%
# where $EXPT can be any of {volatility, electricity, traffic, favorita}, 
# and $OUTPUT_FOLDER denotes the root folder in which experiment outputs are saved.
EXPT='traffic'
OUTPUT_FOLDER='traffic_test'

# %%
# download $EXPT data
# !python3 -m script_download_data $EXPT $OUTPUT_FOLDER
# Out:
# #### Running download script ###
# Resetting data folder...
# Getting traffic data...
# Pulling data from https://archive.ics.uci.edu/ml/machine-learning-databases/00204/PEMS-SF.zip to traffic_test/data/traffic/PEMS-SF.zip
# done
# Unzipping file: traffic_test/data/traffic/PEMS-SF.zip
# Done.
# Aggregating to hourly data
# Completed 50 of 267 rows for PEMS_train
# Completed 100 of 267 rows for PEMS_train
# Completed 150 of 267 rows for PEMS_train
# Completed 200 of 267 rows for PEMS_train
# Completed 250 of 267 rows for PEMS_train
# Completed 50 of 173 rows for PEMS_test
# Completed 100 of 173 rows for PEMS_test
# Completed 150 of 173 rows for PEMS_test
# Shuffling
# Reodering
# Parsing as dataframe
# Processing traj_400000
# Processing traj_400001
# Processing traj_400009
# Processing traj_400010
# Processing traj_400015
# Processing traj_400017
# Processing traj_400025
# Processing traj_400026
# Processing traj_400027
# Processing traj_400030
# Processing traj_400031
# ...

# %%
config = ExperimentConfig(EXPT, OUTPUT_FOLDER)
formatter = config.make_data_formatter()
data_formatter=formatter

raw_data = pd.read_csv(config.data_csv_path, index_col=0)
train, valid, test = data_formatter.split_data(raw_data)
train_samples, valid_samples = data_formatter.get_num_samples_for_calibration()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Formatting train-valid-test splits.
# Setting scalers with training data...

# %%
print (len(raw_data), len(train), len(valid), len(test))
# Out:
# 3997413 3488949 508464 323568

# %%
print (train_samples, valid_samples)
# Out:
# 450000 50000

# %%
raw_data.head()
# Out:
#      values  prev_values  ...  categorical_day_of_week  categorical_time_on_day
# 0  0.019333     0.020933  ...                        4                        1
# 1  0.020200     0.019333  ...                        4                        2
# 2  0.022450     0.020200  ...                        4                        3
# 3  0.029283     0.022450  ...                        4                        4
# 4  0.055483     0.029283  ...                        4                        5
#
# [5 rows x 11 columns]

# %% [markdown]
# # Volatility

# %%
# where $EXPT can be any of {volatility, electricity, traffic, favorita}, 
# and $OUTPUT_FOLDER denotes the root folder in which experiment outputs are saved.
EXPT='volatility'
OUTPUT_FOLDER='volatility_test'

# %%
# download $EXPT data
# !python3 -m script_download_data $EXPT $OUTPUT_FOLDER
# Out:
# #### Running download script ###
# Resetting data folder...
# Getting volatility data...
# Pulling data from https://realized.oxford-man.ox.ac.uk/images/oxfordmanrealizedvolatilityindices.zip to volatility_test/data/volatility/oxfordmanrealizedvolatilityindices.zip
# done
# Unzipping file: volatility_test/data/volatility/oxfordmanrealizedvolatilityindices.zip
# Done.
# Unzip complete. Adding extra inputs
# /content/tft/script_download_data.py:121: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime instead.
#   df['days_from_start'] = (dates - pd.datetime(2000, 1, 3)).days
# Completed formatting, saving to volatility_test/data/volatility/formatted_omi_vol.csv
# Done.
# Download completed.

# %%
config = ExperimentConfig(EXPT, OUTPUT_FOLDER)
formatter = config.make_data_formatter()
data_formatter=formatter

raw_data = pd.read_csv(config.data_csv_path, index_col=0)
train, valid, test = data_formatter.split_data(raw_data)
train_samples, valid_samples = data_formatter.get_num_samples_for_calibration()
# Out:
# Formatting train-valid-test splits.
# Setting scalers with training data...

# %%
print (len(raw_data), len(train), len(valid), len(test))
# Out:
# 144169 109882 15571 18716

# %%
print (train_samples, valid_samples)
# Out:
# -1 -1

# %%
raw_data.head()
# Out:
#                           Symbol  close_time  ...   log_vol  Region
# 2000-01-03 00:00:00+00:00   .AEX    163015.0  ... -8.946668    EMEA
# 2000-01-04 00:00:00+00:00   .AEX    163016.0  ... -8.510686    EMEA
# 2000-01-05 00:00:00+00:00   .AEX    163016.0  ... -7.619135    EMEA
# 2000-01-06 00:00:00+00:00   .AEX    163002.0  ... -8.398790    EMEA
# 2000-01-07 00:00:00+00:00   .AEX    163016.0  ... -8.885257    EMEA
#
# [5 rows x 29 columns]
